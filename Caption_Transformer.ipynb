# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

# %%
import string
import numpy as np
import pandas as pd 
from numpy import array
from PIL import Image
import pickle

import matplotlib.pyplot as plt
import keras
import sys, time, os, warnings 
warnings.filterwarnings("ignore")
import re

import tensorflow as tf
from tqdm import tqdm

from nltk.translate.bleu_score import sentence_bleu

from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
from keras.layers.merge import add
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
image_path = "/content/gdrive/MyDrive/images"
dir_Flickr_text = "/content/gdrive/MyDrive/Flickr8k.token.txt"

jpgs = os.listdir(image_path)
print("Total Images in Dataset = {}".format(len(jpgs)))
# Out:
# Total Images in Dataset = 8091

# %%
file = open(dir_Flickr_text,'r')
text = file.read()
file.close()

datatxt = []
for line in text.split('\n'):
    col = line.split('\t')
    if len(col) == 1:
        continue
    w = col[0].split("#")
    datatxt.append(w + [col[1].lower()])

data = pd.DataFrame(datatxt,columns=["filename","index","caption"])
data = data.reindex(columns =['index','filename','caption'])
data = data[data['filename'] != '2258277193_586949ec62.jpg.1']


uni_filenames = np.unique(data.filename.values)
data.head()
# Out:
#   index  ...                                            caption
# 0     0  ...  a child in a pink dress is climbing up a set o...
# 1     1  ...              a girl going into a wooden building .
# 2     2  ...   a little girl climbing into a wooden playhouse .
# 3     3  ...  a little girl climbing the stairs to her playh...
# 4     4  ...  a little girl in a pink dress going into a woo...
#
# [5 rows x 3 columns]

# %%
from keras.preprocessing.image import load_img, img_to_array

npic = 5
npix = 224
target_size = (npix,npix,3)

count = 1
fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[10:15]:
    filename = image_path + '/' + jpgfnm
    captions = list(data["caption"].loc[data["filename"]==jpgfnm].values)
    image_load = load_img(filename, target_size=target_size)
    
    ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
    ax.imshow(image_load)
    count += 1
    
    ax = fig.add_subplot(npic,2,count)
    plt.axis('off')
    ax.plot()
    ax.set_xlim(0,1)
    ax.set_ylim(0,len(captions))
    for i, caption in enumerate(captions):
        ax.text(0,i,caption,fontsize=20)
    count += 1
plt.show()

# %%
vocabulary = []
for txt in data.caption.values:
    vocabulary.extend(txt.split())
print('Vocabulary Size: %d' % len(set(vocabulary)))
# Out:
# Vocabulary Size: 8918

# %%
img = data["filename"].tolist()
caption = data["caption"].tolist()

# %%
print(f"len(img) : {len(img)}")
print(f"len(caption) : {len(caption)}")
# Out:
# len(img) : 40455
# len(caption) : 40455

# %%
# To remove punctuations
def remove_punctuation(text_original):
    text_no_punctuation = text_original.translate(string.punctuation)
    return(text_no_punctuation)

# To remove single characters
def remove_single_character(text):
    text_len_more_than1 = ""
    for word in text.split():
        if len(word) > 1:
            text_len_more_than1 += " " + word
    return(text_len_more_than1)

# To remove numeric values
def remove_numeric(text):
    text_no_numeric = ""
    for word in text.split():
        isalpha = word.isalpha()
        if isalpha:
            text_no_numeric += " " + word
    return(text_no_numeric)

# %%
def text_clean(text_original):
    text = remove_punctuation(text_original)
    text = remove_single_character(text)
    text = remove_numeric(text)
    return(text)
    
for i, caption in enumerate(data.caption.values):
    newcaption = text_clean(caption)
    data["caption"].iloc[i] = newcaption

# %%
clean_vocabulary = []
for txt in data.caption.values:
    clean_vocabulary.extend(txt.split())
print('Clean Vocabulary Size: %d' % len(set(clean_vocabulary)))
# Out:
# Clean Vocabulary Size: 8357

# %%
PATH = "/content/gdrive/MyDrive/images/"
all_captions = []

for caption  in data["caption"].astype(str):
    caption = '<start> ' + caption+ ' <end>'
    all_captions.append(caption)
all_captions[:10]
# Out:
# ['<start>  child in pink dress is climbing up set of stairs in an entry way <end>',
#  '<start>  girl going into wooden building <end>',
#  '<start>  little girl climbing into wooden playhouse <end>',
#  '<start>  little girl climbing the stairs to her playhouse <end>',
#  '<start>  little girl in pink dress going into wooden cabin <end>',
#  '<start>  black dog and spotted dog are fighting <end>',
#  '<start>  black dog and dog playing with each other on the road <end>',
#  '<start>  black dog and white dog with brown spots are staring at each other in the street <end>',
#  '<start>  two dogs of different breeds looking at each other on the road <end>',
#  '<start>  two dogs on pavement moving toward each other <end>']

# %%
all_img_name_vector = []

for annot in data["filename"]:
    full_image_path = PATH + annot

    all_img_name_vector.append(full_image_path)
all_img_name_vector[:10]
# Out:
# ['/content/gdrive/MyDrive/images/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/images/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/images/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/images/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/images/1000268201_693b08cb0e.jpg',
#  '/content/gdrive/MyDrive/images/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/images/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/images/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/images/1001773457_577c3a7d70.jpg',
#  '/content/gdrive/MyDrive/images/1001773457_577c3a7d70.jpg']

# %%
print(f"len(all_img_name_vector) : {len(all_img_name_vector)}")
print(f"len(all_captions) : {len(all_captions)}")
# Out:
# len(all_img_name_vector) : 40455
# len(all_captions) : 40455

# %%
def data_limiter(num,total_captions,all_img_name_vector):
  train_captions, img_name_vector = shuffle(total_captions,all_img_name_vector,random_state=1)
  train_captions = train_captions[:num]
  img_name_vector = img_name_vector[:num]
  return train_captions,img_name_vector

# %%
train_captions,img_name_vector = data_limiter(40000,all_captions,all_img_name_vector)

# %%
print(f"len(all_img_name_vector) : {len(img_name_vector)}")
print(f"len(all_captions) : {len(train_captions)}")
# Out:
# len(all_img_name_vector) : 40000
# len(all_captions) : 40000

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 506/506 [18:21<00:00,  2.18s/it]

# %% [markdown]
# ### Preprocess and tokenize the captions

# %%
top_k = 5000

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
cap_vector.shape
# Out:
# (40000, 33)

# %% [markdown]
# ### Split the data into training and testing

# %%
img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector,
                                                                    cap_vector,
                                                                    test_size=0.2,
                                                                    random_state=0)

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (32000, 32000, 8000, 8000)

# %% [markdown]
# ### Create a tf.data dataset for training

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
num_steps = len(img_name_train) // BATCH_SIZE

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding_1d(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def positional_encoding_2d(row,col,d_model):
  assert d_model % 2 == 0
  # first d_model/2 encode row embedding and second d_model/2 encode column embedding
  row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
  col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)
  angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
  angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
  #apply sin and cos to odd and even indices resp.
  angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
  angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
  angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
  angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
  pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  #adding -Inf where mask is 1 s.t. value get ignored in softmax

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask=None):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask=None):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask=None, padding_mask=None):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    # using look ahead mask so that during self attention current query dont consider future token
    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    # use padding mask to avoid padded values of both enc_output and dec_input
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff,
               row_size,col_size,rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
    self.pos_encoding = positional_encoding_2d(row_size,col_size, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask=None):
    # shape(x) = (batch_size,seq_len(H*W),features)
    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len(H*W), d_model)
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask=None, padding_mask=None):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size, 
               target_vocab_size,max_pos_encoding, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size,max_pos_encoding, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training,look_ahead_mask=None, dec_padding_mask=None,enc_padding_mask=None):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
num_layer = 4
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = top_k + 1
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %%
transformer = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size,max_pos_encoding=target_vocab_size,rate=dropout_rate)

# %%
def create_masks_decoder(tar):
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  return combined_mask

# %%
@tf.function
def train_step(img_tensor, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  dec_mask = create_masks_decoder(tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(img_tensor, tar_inp, 
                                 True,  
                                 dec_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(tar_real, predictions)

# %%
for epoch in range(20):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  for (batch, (img_tensor, tar)) in enumerate(dataset):
    train_step(img_tensor, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 0.5039 Accuracy 0.2563
# Epoch 1 Batch 50 Loss 0.5635 Accuracy 0.2616
# Epoch 1 Batch 100 Loss 0.5985 Accuracy 0.2591
# Epoch 1 Batch 150 Loss 0.6141 Accuracy 0.2571
# Epoch 1 Batch 200 Loss 0.6210 Accuracy 0.2552
# Epoch 1 Batch 250 Loss 0.6233 Accuracy 0.2548
# Epoch 1 Batch 300 Loss 0.6244 Accuracy 0.2551
# Epoch 1 Batch 350 Loss 0.6258 Accuracy 0.2549
# Epoch 1 Batch 400 Loss 0.6264 Accuracy 0.2547
# Epoch 1 Batch 450 Loss 0.6270 Accuracy 0.2546
# Epoch 1 Loss 0.6268 Accuracy 0.2544
# Time taken for 1 epoch: 122.42731595039368 secs
#
# Epoch 2 Batch 0 Loss 0.5874 Accuracy 0.2456
# Epoch 2 Batch 50 Loss 0.6058 Accuracy 0.2575
# Epoch 2 Batch 100 Loss 0.6118 Accuracy 0.2566
# Epoch 2 Batch 150 Loss 0.6165 Accuracy 0.2553
# Epoch 2 Batch 200 Loss 0.6160 Accuracy 0.2552
# Epoch 2 Batch 250 Loss 0.6156 Accuracy 0.2553
# Epoch 2 Batch 300 Loss 0.6169 Accuracy 0.2550
# Epoch 2 Batch 350 Loss 0.6169 Accuracy 0.2553
# Epoch 2 Batch 400 Loss 0.6166 Accuracy 0.2550
# Epoch 2 Batch 450 Loss 0.6164 Accuracy 0.2549
# Epoch 2 Loss 0.6149 Accuracy 0.2551
# Time taken for 1 epoch: 123.62016916275024 secs
#
# Epoch 3 Batch 0 Loss 0.6557 Accuracy 0.2441
# Epoch 3 Batch 50 Loss 0.6027 Accuracy 0.2576
# Epoch 3 Batch 100 Loss 0.6041 Accuracy 0.2577
# Epoch 3 Batch 150 Loss 0.6095 Accuracy 0.2565
# Epoch 3 Batch 200 Loss 0.6085 Accuracy 0.2559
# Epoch 3 Batch 250 Loss 0.6086 Accuracy 0.2557
# Epoch 3 Batch 300 Loss 0.6057 Accuracy 0.2564
# Epoch 3 Batch 350 Loss 0.6044 Accuracy 0.2564
# Epoch 3 Batch 400 Loss 0.6035 Accuracy 0.2565
# Epoch 3 Batch 450 Loss 0.6017 Accuracy 0.2567
# Epoch 3 Loss 0.6013 Accuracy 0.2566
# Time taken for 1 epoch: 123.6711266040802 secs
#
# Epoch 4 Batch 0 Loss 0.6171 Accuracy 0.2568
# Epoch 4 Batch 50 Loss 0.5800 Accuracy 0.2590
# Epoch 4 Batch 100 Loss 0.5897 Accuracy 0.2595
# Epoch 4 Batch 150 Loss 0.5896 Accuracy 0.2583
# Epoch 4 Batch 200 Loss 0.5902 Accuracy 0.2575
# Epoch 4 Batch 250 Loss 0.5891 Accuracy 0.2578
# Epoch 4 Batch 300 Loss 0.5899 Accuracy 0.2579
# Epoch 4 Batch 350 Loss 0.5904 Accuracy 0.2579
# Epoch 4 Batch 400 Loss 0.5909 Accuracy 0.2575
# Epoch 4 Batch 450 Loss 0.5895 Accuracy 0.2578
# Epoch 4 Loss 0.5875 Accuracy 0.2579
# Time taken for 1 epoch: 123.38273334503174 secs
#
# Epoch 5 Batch 0 Loss 0.7158 Accuracy 0.2358
# Epoch 5 Batch 50 Loss 0.5776 Accuracy 0.2596
# Epoch 5 Batch 100 Loss 0.5817 Accuracy 0.2597
# Epoch 5 Batch 150 Loss 0.5801 Accuracy 0.2596
# Epoch 5 Batch 200 Loss 0.5807 Accuracy 0.2586
# Epoch 5 Batch 250 Loss 0.5795 Accuracy 0.2589
# Epoch 5 Batch 300 Loss 0.5813 Accuracy 0.2588
# Epoch 5 Batch 350 Loss 0.5816 Accuracy 0.2586
# Epoch 5 Batch 400 Loss 0.5807 Accuracy 0.2586
# Epoch 5 Batch 450 Loss 0.5801 Accuracy 0.2586
# Epoch 5 Loss 0.5780 Accuracy 0.2588
# Time taken for 1 epoch: 124.6314537525177 secs
#
# Epoch 6 Batch 0 Loss 0.6504 Accuracy 0.2632
# Epoch 6 Batch 50 Loss 0.5654 Accuracy 0.2608
# Epoch 6 Batch 100 Loss 0.5662 Accuracy 0.2614
# Epoch 6 Batch 150 Loss 0.5692 Accuracy 0.2605
# Epoch 6 Batch 200 Loss 0.5682 Accuracy 0.2597
# Epoch 6 Batch 250 Loss 0.5672 Accuracy 0.2600
# Epoch 6 Batch 300 Loss 0.5665 Accuracy 0.2602
# Epoch 6 Batch 350 Loss 0.5649 Accuracy 0.2603
# Epoch 6 Batch 400 Loss 0.5640 Accuracy 0.2600
# Epoch 6 Batch 450 Loss 0.5636 Accuracy 0.2601
# Epoch 6 Loss 0.5625 Accuracy 0.2601
# Time taken for 1 epoch: 123.66188955307007 secs
#
# Epoch 7 Batch 0 Loss 0.5744 Accuracy 0.2451
# Epoch 7 Batch 50 Loss 0.5532 Accuracy 0.2622
# Epoch 7 Batch 100 Loss 0.5560 Accuracy 0.2622
# Epoch 7 Batch 150 Loss 0.5558 Accuracy 0.2622
# Epoch 7 Batch 200 Loss 0.5534 Accuracy 0.2610
# Epoch 7 Batch 250 Loss 0.5539 Accuracy 0.2609
# Epoch 7 Batch 300 Loss 0.5516 Accuracy 0.2614
# Epoch 7 Batch 350 Loss 0.5505 Accuracy 0.2617
# Epoch 7 Batch 400 Loss 0.5499 Accuracy 0.2615
# Epoch 7 Batch 450 Loss 0.5504 Accuracy 0.2614
# Epoch 7 Loss 0.5497 Accuracy 0.2614
# Time taken for 1 epoch: 123.581707239151 secs
#
# Epoch 8 Batch 0 Loss 0.6182 Accuracy 0.2603
# Epoch 8 Batch 50 Loss 0.5499 Accuracy 0.2623
# Epoch 8 Batch 100 Loss 0.5481 Accuracy 0.2631
# Epoch 8 Batch 150 Loss 0.5480 Accuracy 0.2618
# Epoch 8 Batch 200 Loss 0.5473 Accuracy 0.2616
# Epoch 8 Batch 250 Loss 0.5464 Accuracy 0.2617
# Epoch 8 Batch 300 Loss 0.5444 Accuracy 0.2623
# Epoch 8 Batch 350 Loss 0.5428 Accuracy 0.2623
# Epoch 8 Batch 400 Loss 0.5412 Accuracy 0.2622
# Epoch 8 Batch 450 Loss 0.5402 Accuracy 0.2624
# Epoch 8 Loss 0.5387 Accuracy 0.2624
# Time taken for 1 epoch: 124.17214369773865 secs
#
# Epoch 9 Batch 0 Loss 0.5675 Accuracy 0.2368
# Epoch 9 Batch 50 Loss 0.5374 Accuracy 0.2634
# Epoch 9 Batch 100 Loss 0.5380 Accuracy 0.2645
# Epoch 9 Batch 150 Loss 0.5369 Accuracy 0.2637
# Epoch 9 Batch 200 Loss 0.5370 Accuracy 0.2630
# Epoch 9 Batch 250 Loss 0.5360 Accuracy 0.2631
# Epoch 9 Batch 300 Loss 0.5342 Accuracy 0.2631
# Epoch 9 Batch 350 Loss 0.5329 Accuracy 0.2633
# Epoch 9 Batch 400 Loss 0.5328 Accuracy 0.2630
# Epoch 9 Batch 450 Loss 0.5323 Accuracy 0.2632
# Epoch 9 Loss 0.5305 Accuracy 0.2633
# Time taken for 1 epoch: 123.67373585700989 secs
#
# Epoch 10 Batch 0 Loss 0.5642 Accuracy 0.2622
# Epoch 10 Batch 50 Loss 0.5276 Accuracy 0.2631
# Epoch 10 Batch 100 Loss 0.5254 Accuracy 0.2653
# Epoch 10 Batch 150 Loss 0.5252 Accuracy 0.2649
# Epoch 10 Batch 200 Loss 0.5249 Accuracy 0.2637
# Epoch 10 Batch 250 Loss 0.5234 Accuracy 0.2641
# Epoch 10 Batch 300 Loss 0.5229 Accuracy 0.2644
# Epoch 10 Batch 350 Loss 0.5218 Accuracy 0.2644
# Epoch 10 Batch 400 Loss 0.5197 Accuracy 0.2644
# Epoch 10 Batch 450 Loss 0.5197 Accuracy 0.2644
# Epoch 10 Loss 0.5186 Accuracy 0.2645
# Time taken for 1 epoch: 123.293869972229 secs
#
# Epoch 11 Batch 0 Loss 0.5463 Accuracy 0.2485
# Epoch 11 Batch 50 Loss 0.5192 Accuracy 0.2643
# Epoch 11 Batch 100 Loss 0.5157 Accuracy 0.2660
# Epoch 11 Batch 150 Loss 0.5154 Accuracy 0.2659
# Epoch 11 Batch 200 Loss 0.5130 Accuracy 0.2651
# Epoch 11 Batch 250 Loss 0.5124 Accuracy 0.2654
# Epoch 11 Batch 300 Loss 0.5105 Accuracy 0.2655
# Epoch 11 Batch 350 Loss 0.5099 Accuracy 0.2656
# Epoch 11 Batch 400 Loss 0.5095 Accuracy 0.2656
# Epoch 11 Batch 450 Loss 0.5097 Accuracy 0.2655
# Epoch 11 Loss 0.5085 Accuracy 0.2656
# Time taken for 1 epoch: 124.58353805541992 secs
#
# Epoch 12 Batch 0 Loss 0.6041 Accuracy 0.2622
# Epoch 12 Batch 50 Loss 0.5067 Accuracy 0.2659
# Epoch 12 Batch 100 Loss 0.5031 Accuracy 0.2680
# Epoch 12 Batch 150 Loss 0.5046 Accuracy 0.2668
# Epoch 12 Batch 200 Loss 0.5012 Accuracy 0.2665
# Epoch 12 Batch 250 Loss 0.5015 Accuracy 0.2666
# Epoch 12 Batch 300 Loss 0.5010 Accuracy 0.2668
# Epoch 12 Batch 350 Loss 0.5008 Accuracy 0.2668
# Epoch 12 Batch 400 Loss 0.5000 Accuracy 0.2665
# Epoch 12 Batch 450 Loss 0.4993 Accuracy 0.2665
# Epoch 12 Loss 0.4972 Accuracy 0.2667
# Time taken for 1 epoch: 123.81099939346313 secs
#
# Epoch 13 Batch 0 Loss 0.5909 Accuracy 0.2588
# Epoch 13 Batch 50 Loss 0.4978 Accuracy 0.2667
# Epoch 13 Batch 100 Loss 0.4965 Accuracy 0.2687
# Epoch 13 Batch 150 Loss 0.4967 Accuracy 0.2679
# Epoch 13 Batch 200 Loss 0.4958 Accuracy 0.2669
# Epoch 13 Batch 250 Loss 0.4948 Accuracy 0.2672
# Epoch 13 Batch 300 Loss 0.4912 Accuracy 0.2676
# Epoch 13 Batch 350 Loss 0.4895 Accuracy 0.2678
# Epoch 13 Batch 400 Loss 0.4878 Accuracy 0.2677
# Epoch 13 Batch 450 Loss 0.4870 Accuracy 0.2677
# Epoch 13 Loss 0.4866 Accuracy 0.2679
# Time taken for 1 epoch: 124.11468362808228 secs
#
# Epoch 14 Batch 0 Loss 0.5452 Accuracy 0.2603
# Epoch 14 Batch 50 Loss 0.4902 Accuracy 0.2667
# Epoch 14 Batch 100 Loss 0.4880 Accuracy 0.2683
# Epoch 14 Batch 150 Loss 0.4872 Accuracy 0.2685
# Epoch 14 Batch 200 Loss 0.4873 Accuracy 0.2673
# Epoch 14 Batch 250 Loss 0.4857 Accuracy 0.2677
# Epoch 14 Batch 300 Loss 0.4837 Accuracy 0.2682
# Epoch 14 Batch 350 Loss 0.4822 Accuracy 0.2685
# Epoch 14 Batch 400 Loss 0.4824 Accuracy 0.2682
# Epoch 14 Batch 450 Loss 0.4825 Accuracy 0.2682
# Epoch 14 Loss 0.4812 Accuracy 0.2682
# Time taken for 1 epoch: 124.01385974884033 secs
#
# Epoch 15 Batch 0 Loss 0.4972 Accuracy 0.2700
# Epoch 15 Batch 50 Loss 0.4627 Accuracy 0.2704
# Epoch 15 Batch 100 Loss 0.4660 Accuracy 0.2714
# Epoch 15 Batch 150 Loss 0.4689 Accuracy 0.2701
# Epoch 15 Batch 200 Loss 0.4692 Accuracy 0.2696
# Epoch 15 Batch 250 Loss 0.4713 Accuracy 0.2697
# Epoch 15 Batch 300 Loss 0.4689 Accuracy 0.2697
# Epoch 15 Batch 350 Loss 0.4697 Accuracy 0.2697
# Epoch 15 Batch 400 Loss 0.4695 Accuracy 0.2697
# Epoch 15 Batch 450 Loss 0.4690 Accuracy 0.2697
# Epoch 15 Loss 0.4676 Accuracy 0.2697
# Time taken for 1 epoch: 124.16108989715576 secs
#
# Epoch 16 Batch 0 Loss 0.5178 Accuracy 0.2446
# Epoch 16 Batch 50 Loss 0.4648 Accuracy 0.2698
# Epoch 16 Batch 100 Loss 0.4651 Accuracy 0.2709
# Epoch 16 Batch 150 Loss 0.4661 Accuracy 0.2706
# Epoch 16 Batch 200 Loss 0.4659 Accuracy 0.2698
# Epoch 16 Batch 250 Loss 0.4651 Accuracy 0.2698
# Epoch 16 Batch 300 Loss 0.4650 Accuracy 0.2700
# Epoch 16 Batch 350 Loss 0.4637 Accuracy 0.2702
# Epoch 16 Batch 400 Loss 0.4630 Accuracy 0.2701
# Epoch 16 Batch 450 Loss 0.4625 Accuracy 0.2703
# Epoch 16 Loss 0.4620 Accuracy 0.2702
# Time taken for 1 epoch: 123.28507947921753 secs
#
# Epoch 17 Batch 0 Loss 0.5187 Accuracy 0.2651
# Epoch 17 Batch 50 Loss 0.4527 Accuracy 0.2720
# Epoch 17 Batch 100 Loss 0.4534 Accuracy 0.2724
# Epoch 17 Batch 150 Loss 0.4533 Accuracy 0.2723
# Epoch 17 Batch 200 Loss 0.4551 Accuracy 0.2711
# Epoch 17 Batch 250 Loss 0.4545 Accuracy 0.2712
# Epoch 17 Batch 300 Loss 0.4532 Accuracy 0.2714
# Epoch 17 Batch 350 Loss 0.4536 Accuracy 0.2714
# Epoch 17 Batch 400 Loss 0.4529 Accuracy 0.2712
# Epoch 17 Batch 450 Loss 0.4534 Accuracy 0.2712
# Epoch 17 Loss 0.4525 Accuracy 0.2713
# Time taken for 1 epoch: 124.71478915214539 secs
#
# Epoch 18 Batch 0 Loss 0.4505 Accuracy 0.2573
# Epoch 18 Batch 50 Loss 0.4580 Accuracy 0.2714
# Epoch 18 Batch 100 Loss 0.4545 Accuracy 0.2725
# Epoch 18 Batch 150 Loss 0.4528 Accuracy 0.2720
# Epoch 18 Batch 200 Loss 0.4531 Accuracy 0.2711
# Epoch 18 Batch 250 Loss 0.4516 Accuracy 0.2716
# Epoch 18 Batch 300 Loss 0.4503 Accuracy 0.2719
# Epoch 18 Batch 350 Loss 0.4488 Accuracy 0.2719
# Epoch 18 Batch 400 Loss 0.4481 Accuracy 0.2717
# Epoch 18 Batch 450 Loss 0.4474 Accuracy 0.2720
# Epoch 18 Loss 0.4461 Accuracy 0.2719
# Time taken for 1 epoch: 123.582848072052 secs
#
# Epoch 19 Batch 0 Loss 0.5063 Accuracy 0.2534
# Epoch 19 Batch 50 Loss 0.4438 Accuracy 0.2732
# Epoch 19 Batch 100 Loss 0.4451 Accuracy 0.2737
# Epoch 19 Batch 150 Loss 0.4452 Accuracy 0.2730
# Epoch 19 Batch 200 Loss 0.4438 Accuracy 0.2724
# Epoch 19 Batch 250 Loss 0.4429 Accuracy 0.2726
# Epoch 19 Batch 300 Loss 0.4414 Accuracy 0.2728
# Epoch 19 Batch 350 Loss 0.4411 Accuracy 0.2728
# Epoch 19 Batch 400 Loss 0.4397 Accuracy 0.2727
# Epoch 19 Batch 450 Loss 0.4404 Accuracy 0.2728
# Epoch 19 Loss 0.4388 Accuracy 0.2728
# Time taken for 1 epoch: 124.13740348815918 secs
#
# Epoch 20 Batch 0 Loss 0.4644 Accuracy 0.2876
# Epoch 20 Batch 50 Loss 0.4392 Accuracy 0.2730
# Epoch 20 Batch 100 Loss 0.4349 Accuracy 0.2742
# Epoch 20 Batch 150 Loss 0.4370 Accuracy 0.2737
# Epoch 20 Batch 200 Loss 0.4359 Accuracy 0.2730
# Epoch 20 Batch 250 Loss 0.4348 Accuracy 0.2730
# Epoch 20 Batch 300 Loss 0.4336 Accuracy 0.2735
# Epoch 20 Batch 350 Loss 0.4342 Accuracy 0.2735
# Epoch 20 Batch 400 Loss 0.4337 Accuracy 0.2732
# Epoch 20 Batch 450 Loss 0.4340 Accuracy 0.2732
# Epoch 20 Loss 0.4325 Accuracy 0.2732
# Time taken for 1 epoch: 124.03679013252258 secs

# %%
transformer.save_weights('image_caption_transformer_45_3.h5')

# %%
def evaluate(image):

  temp_input = tf.expand_dims(load_image(image)[0], 0)
  img_tensor_val = image_features_extract_model(temp_input)
  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
  
  start_token = tokenizer.word_index['<start>']
  end_token = tokenizer.word_index['<end>']
   
  #decoder input is start token.
  decoder_input = [start_token]
  output = tf.expand_dims(decoder_input, 0) #tokens
  result = [] #word list

  for i in range(100):
      dec_mask = create_masks_decoder(output)
  
      # predictions.shape == (batch_size, seq_len, vocab_size)
      predictions, attention_weights = transformer(img_tensor_val,output,False,dec_mask)
      
      # select the last word from the seq_len dimension
      predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

      predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)
      # return the result if the predicted_id is equal to the end token
      if predicted_id == end_token:
          return result,tf.squeeze(output, axis=0), attention_weights
      # concatentate the predicted_id to the output which is given to the decoder
      # as its input.
      result.append(tokenizer.index_word[int(predicted_id)])
      output = tf.concat([output, predicted_id], axis=-1)

  return result,tf.squeeze(output, axis=0), attention_weights

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 7.993987303984694
# BLEU-2 score: 11.30520526273349
# BLEU-3 score: 12.986270688205781
# BLEU-4 score: 13.444230535008868
# Real Caption: little white and black dog is leaping over big brown dog head in field of green grass
# Predicted Caption: the dog jumps over the dog

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 18.612544500887303
# BLEU-2 score: 14.215565675175021
# BLEU-3 score: 26.13412746974997
# BLEU-4 score: 30.431192394822187
# Real Caption: man performing trick on skateboard at graffiti covered skate park
# Predicted Caption: young boy is doing tricks on skateboard

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# BLEU-1 score: 22.22222222222222
# BLEU-2 score: 47.14045207910317
# BLEU-3 score: 63.684866956664344
# BLEU-4 score: 68.65890479690393
# Real Caption: black and white dog is running between yellow poles
# Predicted Caption: dog and line of posts on an obstacle course

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
print(rid, image)
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
caption,result,attention_weights = evaluate(image)

first = real_caption.split(' ', 1)[1]
real_caption = first.rsplit(' ', 1)[0]

#remove "<unk>" in result
for i in caption:
    if i=="<unk>":
        caption.remove(i)

for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

#remove <end> from result         
result_join = ' '.join(caption)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = caption
score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
print(f"BLEU-1 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
print(f"BLEU-2 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
print(f"BLEU-3 score: {score*100}")
score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
print(f"BLEU-4 score: {score*100}")

print ('Real Caption:', real_caption)
print ('Predicted Caption:', ' '.join(caption))
temp_image = np.array(Image.open(image))
plt.imshow(temp_image)
# Out:
# 1774 /content/gdrive/MyDrive/images/354642192_3b7666a2dd.jpg
# BLEU-1 score: 28.57142857142857
# BLEU-2 score: 53.45224838248488
# BLEU-3 score: 68.67198272427282
# BLEU-4 score: 73.11104457090248
# Real Caption: person swims in pool by waterfall
# Predicted Caption: person is in the water near rocks

# %%
import pickle

# saving
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
rid = np.random.randint(0, len(img_name_val))
print(img_name_val)
# Out:
# ['/content/gdrive/MyDrive/images/2352414953_10f3cd0f1f.jpg', '/content/gdrive/MyDrive/images/3081182021_22cfa18dd4.jpg', '/content/gdrive/MyDrive/images/3104909823_0f41dd8be6.jpg', '/content/gdrive/MyDrive/images/2956413620_d59de03a06.jpg', '/content/gdrive/MyDrive/images/1501297480_8db52c15b0.jpg', '/content/gdrive/MyDrive/images/2285741931_07159a21f2.jpg', '/content/gdrive/MyDrive/images/2258951972_92763fddab.jpg', '/content/gdrive/MyDrive/images/3537520829_aab733e16c.jpg', '/content/gdrive/MyDrive/images/3404552106_f516df0f5b.jpg', '/content/gdrive/MyDrive/images/2463067409_78188c584c.jpg', '/content/gdrive/MyDrive/images/2053777548_108e54c826.jpg', '/content/gdrive/MyDrive/images/3324375078_9441f72898.jpg', '/content/gdrive/MyDrive/images/3182558164_488b819f14.jpg', '/content/gdrive/MyDrive/images/3477681171_b1bb8b211d.jpg', '/content/gdrive/MyDrive/images/2554570943_122da6438f.jpg', '/content/gdrive/MyDrive/images/2949497756_be8e58e6bd.jpg', '/content/gdrive/MyDrive/images/3603064161_a8f3b6455d.jpg', '/content/gdrive/MyDrive/images/2874728371_ccd6db87f3.jpg', '/content/gdrive/MyDrive/images/1806580620_a8fe0fb9f8.jpg', '/content/gdrive/MyDrive/images/3506560025_8d0f4f9ac4.jpg', '/content/gdrive/MyDrive/images/349889354_4b2889a9bd.jpg', '/content/gdrive/MyDrive/images/3348385580_10b53391f9.jpg', '/content/gdrive/MyDrive/images/3587092143_c63030ed6d.jpg', '/content/gdrive/MyDrive/images/3539767254_c598b8e6c7.jpg', '/content/gdrive/MyDrive/images/2272548482_0b4aec5cdd.jpg', '/content/gdrive/MyDrive/images/2705793985_007cc703fb.jpg', '/content/gdrive/MyDrive/images/3431261634_c73360406a.jpg', '/content/gdrive/MyDrive/images/3034585889_388d6ffcc0.jpg', '/content/gdrive/MyDrive/images/3441701164_6dbbdf1bce.jpg', '/content/gdrive/MyDrive/images/2142232919_c857a09dd7.jpg', '/content/gdrive/MyDrive/images/2685139184_4ff45e0f76.jpg', '/content/gdrive/MyDrive/images/537559285_29be110134.jpg', '/content/gdrive/MyDrive/images/3562470436_6e193643ce.jpg', '/content/gdrive/MyDrive/images/3486324591_9f5eeb24b9.jpg', '/content/gdrive/MyDrive/images/3413806271_17b7e102aa.jpg', '/content/gdrive/MyDrive/images/566794440_f9ec673a2f.jpg', '/content/gdrive/MyDrive/images/3455898176_f0e003ce58.jpg', '/content/gdrive/MyDrive/images/2774362575_7543b8bf19.jpg', '/content/gdrive/MyDrive/images/661757041_61e131e913.jpg', '/content/gdrive/MyDrive/images/3222842866_cb85243ce4.jpg', '/content/gdrive/MyDrive/images/311196733_03966b4836.jpg', '/content/gdrive/MyDrive/images/428796930_476a3d6395.jpg', '/content/gdrive/MyDrive/images/2836703077_fa9c736203.jpg', '/content/gdrive/MyDrive/images/3164347907_2813f8ff0b.jpg', '/content/gdrive/MyDrive/images/2708634088_a4686be24c.jpg', '/content/gdrive/MyDrive/images/3537520829_aab733e16c.jpg', '/content/gdrive/MyDrive/images/3567604049_da9e1be4ba.jpg', '/content/gdrive/MyDrive/images/2151056407_c9c09b0a02.jpg', '/content/gdrive/MyDrive/images/544576742_283b65fa0d.jpg', '/content/gdrive/MyDrive/images/260392825_ea61660633.jpg', '/content/gdrive/MyDrive/images/514222303_cb98584536.jpg', '/content/gdrive/MyDrive/images/3614582606_16bd88dab2.jpg', '/content/gdrive/MyDrive/images/273248777_eaf0288ab3.jpg', '/content/gdrive/MyDrive/images/1541272333_1624b22546.jpg', '/content/gdrive/MyDrive/images/733752482_ee01a419e5.jpg', '/content/gdrive/MyDrive/images/3122888809_9ae9b4b9b2.jpg', '/content/gdrive/MyDrive/images/1501985304_8c50093004.jpg', '/content/gdrive/MyDrive/images/3397803103_8a46d716f4.jpg', '/content/gdrive/MyDrive/images/2501968935_02f2cd8079.jpg', '/content/gdrive/MyDrive/images/2612040125_0a93889f06.jpg', '/content/gdrive/MyDrive/images/3332136681_9aecf101fd.jpg', '/content/gdrive/MyDrive/images/445861800_75fc6a8c16.jpg', '/content/gdrive/MyDrive/images/3184891327_8785194e3c.jpg', '/content/gdrive/MyDrive/images/2346401538_f5e8da66fc.jpg', '/content/gdrive/MyDrive/images/3510218982_318f738b76.jpg', '/content/gdrive/MyDrive/images/2726262796_03bd63a155.jpg', '/content/gdrive/MyDrive/images/247618600_239eeac40 ...

# %%
start_token = tokenizer.word_index['<start>']
end_token = tokenizer.word_index['<end>']
# select random image from validation data

bleu1 = 0
bleu2 = 0
bleu3 = 0
bleu4 = 0

for x in range(0, int(len(img_name_val)/5)):
  rid = np.random.randint(0, len(img_name_val))
  image = img_name_val[rid]
  print(rid, image)
  real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
  caption,result,attention_weights = evaluate(image)

  first = real_caption.split(' ', 1)[1]
  real_caption = first.rsplit(' ', 1)[0]

  #remove "<unk>" in result
  for i in caption:
      if i=="<unk>":
          caption.remove(i)

  for i in real_caption:
      if i=="<unk>":
          real_caption.remove(i)

  #remove <end> from result         
  result_join = ' '.join(caption)
  result_final = result_join.rsplit(' ', 1)[0]

  real_appn = []
  real_appn.append(real_caption.split())
  reference = real_appn
  candidate = caption
  print ('img_name:', image)
  score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
  print(f"BLEU-1 score: {score*100}")
  bleu1 += score * 100
  score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
  print(f"BLEU-2 score: {score*100}")
  bleu2 += score * 100
  score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
  print(f"BLEU-3 score: {score*100}")
  bleu3 += score * 100
  score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
  print(f"BLEU-4 score: {score*100}")
  bleu4 += score * 100
  print ('Real Caption:', real_caption)
  print ('Predicted Caption:', ' '.join(caption))
  print("\n")
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# 2469 /content/gdrive/MyDrive/images/319847643_df7c2a1d25.jpg
# img_name: /content/gdrive/MyDrive/images/319847643_df7c2a1d25.jpg
# BLEU-1 score: 10.735389901075512
# BLEU-2 score: 28.4031719055601
# BLEU-3 score: 41.916638802381996
# BLEU-4 score: 46.1999336994571
# Real Caption: girl <unk> when drops of water come her way
# Predicted Caption: young boy drinks water from water gun
#
#
# 6041 /content/gdrive/MyDrive/images/3175446111_681a89f873.jpg
# img_name: /content/gdrive/MyDrive/images/3175446111_681a89f873.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 50.0
# BLEU-3 score: 65.9753955386447
# BLEU-4 score: 70.71067811865476
# Real Caption: lot of people playing games at an arcade
# Predicted Caption: man and woman are at carnival playing tug of war with rocket
#
#
# 4440 /content/gdrive/MyDrive/images/432167214_c17fcc1a2d.jpg
# img_name: /content/gdrive/MyDrive/images/432167214_c17fcc1a2d.jpg
# BLEU-1 score: 18.962969685355986
# BLEU-2 score: 8.276118474694925
# BLEU-3 score: 12.937014186724543
# BLEU-4 score: 14.465581391613888
# Real Caption: man in blue and yellow jacket holding religious sign stands in street with people behind him on the sidewalk
# Predicted Caption: man is standing on the street holding sign
#
#
# 2082 /content/gdrive/MyDrive/images/3241487502_f4f0cc4a8a.jpg
# img_name: /content/gdrive/MyDrive/images/3241487502_f4f0cc4a8a.jpg
# BLEU-1 score: 27.590958087858176
# BLEU-2 score: 17.02950904648076
# BLEU-3 score: 23.174132396431407
# BLEU-4 score: 25.02959502557595
# Real Caption: two light tan dogs of the same breed but different size are running in the woods
# Predicted Caption: two dogs are running around in the ground
#
#
# 1477 /content/gdrive/MyDrive/images/2085255128_61224cc47f.jpg
# img_name: /content/gdrive/MyDrive/images/2085255128_61224cc47f.jpg
# BLEU-1 score: 11.409269311835377
# BLEU-2 score: 24.20271509634711
# BLEU-3 score: 32.69690091886452
# BLEU-4 score: 35.250657096759426
# Real Caption: boy high in the air above the dirt and water near the red rock cliffs
# Predicted Caption: young man in orange shorts jumping over still water
#
#
# 6954 /content/gdrive/MyDrive/images/3635991166_f95304af0a.jpg
# img_name: /content/gdrive/MyDrive/images/3635991166_f95304af0a.jpg
# BLEU-1 score: 4.93193927883213
# BLEU-2 score: 11.028151488369934
# BLEU-3 score: 15.21586771959164
# BLEU-4 score: 16.490932887256967
# Real Caption: there are four smiling boys with smiles on playground with their ball
# Predicted Caption: the children are playing soccer
#
#
# 2201 /content/gdrive/MyDrive/images/1312020846_5abb4a9be2.jpg
# img_name: /content/gdrive/MyDrive/images/1312020846_5abb4a9be2.jpg
# BLEU-1 score: 23.076923076923077
# BLEU-2 score: 48.038446141526144
# BLEU-3 score: 64.41001061420619
# BLEU-4 score: 69.30977286178778
# Real Caption: two puppies run across flat stones in garden area
# Predicted Caption: two small dogs run along the edge of stone wall nearby heavily area
#
#
# 5887 /content/gdrive/MyDrive/images/519061891_320061864e.jpg
# img_name: /content/gdrive/MyDrive/images/519061891_320061864e.jpg
# BLEU-1 score: 10.735389901075512
# BLEU-2 score: 28.4031719055601
# BLEU-3 score: 41.916638802381996
# BLEU-4 score: 46.1999336994571
# Real Caption: young child splashes in green and yellow wading pool
# Predicted Caption: baby is taking bath in the water
#
#
# 5201 /content/gdrive/MyDrive/images/1527333441_af65636a74.jpg
# img_name: /content/gdrive/MyDrive/images/1527333441_af65636a74.jpg
# BLEU-1 score: 23.076923076923077
# BLEU-2 score: 19.61161351381841
# BLEU-3 score: 18.326949791536798
# BLEU-4 score: 24.316915840399716
# Real Caption: man in blue tank top showing his <unk>
# Predicted Caption: man in blue shirt and jeans stands behind sign that says mark finley
#
#
# 28 /content/gdrive/MyDrive/images/3441701164_6dbbdf1bce.jpg
# img_name: /content/gdrive/MyDrive/images/3441701164_6dbbdf1bce.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: dirt bike rider holds up his finger
# Predicted Caption: the number motorcycle racer in yellow and black uniform is going around corner
#
#
# 1156 /content/gdrive/MyDrive/images/3052196390_c59dd24ca8.jpg
# img_name: /content/gdrive/MyDrive/images/3052196390_c59dd24ca8.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: little kids enjoy sprinklers by running through them outdoors
# Predicted Caption: children play in water spray
#
#
# 3695 /content/gdrive/MyDrive/images/3160531982_37f5636b8a.jpg
# img_name: /content/gdrive/MyDrive/images/3160531982_37f5636b8a.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: person <unk> at sundown
# Predicted Caption: parachute is making their landing as the sunsets behind him
#
#
# 2729 /content/gdrive/MyDrive/images/1931690777_897a7d8ab6.jpg
# img_name: /content/gdrive/MyDrive/images/1931690777_897a7d8ab6.jpg
# BLEU-1 score: 40.0
# BLEU-2 score: 21.08185106778919
# BLEU-3 score: 39.29571945508051
# BLEU-4 score: 45.91497693322865
# Real Caption: four boys jumping into an inground pool
# Predicted Caption: four boys doing cannonball jump in unison into the pool
#
#
# 6325 /content/gdrive/MyDrive/images/1526181215_c1a94325ae.jpg
# img_name: /content/gdrive/MyDrive/images/1526181215_c1a94325ae.jpg
# BLEU-1 score: 50.0
# BLEU-2 score: 26.726124191242434
# BLEU-3 score: 45.30661222656875
# BLEU-4 score: 51.697315395717055
# Real Caption: dog is jumping into the water
# Predicted Caption: light colored dog jumping out of the water
#
#
# 1675 /content/gdrive/MyDrive/images/2977379863_2e8d7a104e.jpg
# img_name: /content/gdrive/MyDrive/images/2977379863_2e8d7a104e.jpg
# BLEU-1 score: 22.22222222222222
# BLEU-2 score: 47.14045207910317
# BLEU-3 score: 63.684866956664344
# BLEU-4 score: 68.65890479690393
# Real Caption: children in costumes standing in line
# Predicted Caption: girl in black cape with group of other children
#
#
# 1666 /content/gdrive/MyDrive/images/3497236690_a48bf7ac42.jpg
# img_name: /content/gdrive/MyDrive/images/3497236690_a48bf7ac42.jpg
# BLEU-1 score: 60.0
# BLEU-2 score: 36.514837167011066
# BLEU-3 score: 29.278891135523562
# BLEU-4 score: 35.93041119630843
# Real Caption: man in black jersey is standing in gym
# Predicted Caption: man is standing in the middle of gym wearing jersey
#
#
# 635 /content/gdrive/MyDrive/images/241345522_c3c266a02a.jpg
# img_name: /content/gdrive/MyDrive/images/241345522_c3c266a02a.jpg
# BLEU-1 score: 25.500152032774785
# BLEU-2 score: 13.523497817747234
# BLEU-3 score: 24.107020450214105
# BLEU-4 score: 27.855256475695363
# Real Caption: an american footballer in white and purple strip is making run with the ball
# Predicted Caption: man in white jersey is running on the grass
#
#
# 2841 /content/gdrive/MyDrive/images/2963672852_c28043bb2c.jpg
# img_name: /content/gdrive/MyDrive/images/2963672852_c28043bb2c.jpg
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: man walks over small sign carrying his bicycle
# Predicted Caption: man is sitting on bike and wearing black cap
#
#
# 2059 /content/gdrive/MyDrive/images/1357724865_4faf4e1418.jpg
# img_name: /content/gdrive/MyDrive/images/1357724865_4faf4e1418.jpg
# BLEU-1 score: 36.36363636363637
# BLEU-2 score: 60.30226891555272
# BLEU-3 score: 73.82444519647268
# BLEU-4 score: 77.65453555044466
# Real Caption: man walks into river at the bottom of small waterfall
# Predicted Caption: man in grey suit is standing in the water at waterfall
#
#
# 7168 /content/gdrive/MyDrive/images/2883907436_82bf4a36b8.jpg
# img_name: /content/gdrive/MyDrive/images/2883907436_82bf4a36b8.jpg
# BLEU-1 score: 11.6689775872393
# BLEU-2 score: 31.956811237765866
# BLEU-3 score: 47.81626944249067
# BLEU-4 score: 52.88454269158854
# Real Caption: an old man with large belly is next to filled shopping cart and dog on the street
# Predicted Caption: black haired woman in red with in her right hand while holding small white dog
#
#
# 799 /content/gdrive/MyDrive/images/3016708786_3591106cca.jpg
# img_name: /content/gdrive/MyDrive/images/3016708786_3591106cca.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: the three people are playing around with fake knife
# Predicted Caption: two men hold young girl between them for meal
#
#
# 2320 /content/gdrive/MyDrive/images/2629334536_11f2d49e05.jpg
# img_name: /content/gdrive/MyDrive/images/2629334536_11f2d49e05.jpg
# BLEU-1 score: 10.000000000000002
# BLEU-2 score: 31.6227766016838
# BLEU-3 score: 50.11872336272724
# BLEU-4 score: 56.23413251903491
# Real Caption: young girl plays on swing
# Predicted Caption: baby in blue shirt with red eyes sits in swing
#
#
# 4321 /content/gdrive/MyDrive/images/3113322995_13781860f2.jpg
# img_name: /content/gdrive/MyDrive/images/3113322995_13781860f2.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: sled and dogs mushing
# Predicted Caption: group of people stand in the snow in line
#
#
# 2972 /content/gdrive/MyDrive/images/42637987_866635edf6.jpg
# img_name: /content/gdrive/MyDrive/images/42637987_866635edf6.jpg
# BLEU-1 score: 19.885318151430436
# BLEU-2 score: 42.183129932785214
# BLEU-3 score: 56.987722838915545
# BLEU-4 score: 61.43868746168435
# Real Caption: people sit on park bench while others jog on path
# Predicted Caption: group of people are sitting on sidewalk near building
#
#
# 6315 /content/gdrive/MyDrive/images/2954584849_3c2899f319.jpg
# img_name: /content/gdrive/MyDrive/images/2954584849_3c2899f319.jpg
# BLEU-1 score: 15.163266492815836
# BLEU-2 score: 30.326532985631673
# BLEU-3 score: 40.01610018085611
# BLEU-4 score: 42.88819424803535
# Real Caption: couple of rugby players jumping in the air to get the ball
# Predicted Caption: group of men are playing in soccer game
#
#
# 2657 /content/gdrive/MyDrive/images/3249738122_decde6c117.jpg
# img_name: /content/gdrive/MyDrive/images/3249738122_decde6c117.jpg
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: participant in dog sled race passes onlookers
# Predicted Caption: man is walking in the snow with his dogs
#
#
# 4063 /content/gdrive/MyDrive/images/2381102729_12fc4d4c76.jpg
# img_name: /content/gdrive/MyDrive/images/2381102729_12fc4d4c76.jpg
# BLEU-1 score: 60.0
# BLEU-2 score: 54.77225575051662
# BLEU-3 score: 50.11872336272722
# BLEU-4 score: 56.23413251903491
# Real Caption: dog jumps over some water
# Predicted Caption: the dog jumps over stream
#
#
# 7528 /content/gdrive/MyDrive/images/3053415073_5b667230ed.jpg
# img_name: /content/gdrive/MyDrive/images/3053415073_5b667230ed.jpg
# BLEU-1 score: 16.666666666666668
# BLEU-2 score: 40.8248290463863
# BLEU-3 score: 58.419068106786554
# BLEU-4 score: 63.89431042462724
# Real Caption: the skier is wearing yellow jumpsuit and sliding across yellow rail
# Predicted Caption: person in yellow jacket and blue hat on snowboard with run down
#
#
# 5308 /content/gdrive/MyDrive/images/756004341_1a816df714.jpg
# img_name: /content/gdrive/MyDrive/images/756004341_1a816df714.jpg
# BLEU-1 score: 23.076923076923077
# BLEU-2 score: 13.867504905630728
# BLEU-3 score: 30.56321221169349
# BLEU-4 score: 37.23909894939823
# Real Caption: two children in yard wearing sunglasses with play structure behind them
# Predicted Caption: two young women wearing sunglasses hold piece of plastic lot of plastic signs
#
#
# 2107 /content/gdrive/MyDrive/images/498957941_f0eda42787.jpg
# img_name: /content/gdrive/MyDrive/images/498957941_f0eda42787.jpg
# BLEU-1 score: 8.333333333333332
# BLEU-2 score: 28.867513459481287
# BLEU-3 score: 47.45102806263551
# BLEU-4 score: 53.7284965911771
# Real Caption: young boy runs
# Predicted Caption: the little boy in the blue shirt is running through the court
#
#
# 4613 /content/gdrive/MyDrive/images/2653552905_4301449235.jpg
# img_name: /content/gdrive/MyDrive/images/2653552905_4301449235.jpg
# BLEU-1 score: 54.54545454545454
# BLEU-2 score: 40.45199174779452
# BLEU-3 score: 30.053232635449127
# BLEU-4 score: 36.72056269893592
# Real Caption: two men stand in front of large building
# Predicted Caption: two men are standing on path in front of white building
#
#
# 35 /content/gdrive/MyDrive/images/566794440_f9ec673a2f.jpg
# img_name: /content/gdrive/MyDrive/images/566794440_f9ec673a2f.jpg
# BLEU-1 score: 12.500000000000004
# BLEU-2 score: 35.35533905932738
# BLEU-3 score: 53.588673126814655
# BLEU-4 score: 59.46035575013605
# Real Caption: girls with baseball gloves walking across baseball field
# Predicted Caption: woman in yellow shirt just swings at baseball
#
#
# 5656 /content/gdrive/MyDrive/images/864290968_eccb46d5ab.jpg
# img_name: /content/gdrive/MyDrive/images/864290968_eccb46d5ab.jpg
# BLEU-1 score: 14.486606950235942
# BLEU-2 score: 25.091539267089075
# BLEU-3 score: 31.257306787590522
# BLEU-4 score: 33.02232277439296
# Real Caption: an elder man with long grey beard riding on the bus
# Predicted Caption: man sitting in an airplane seat
#
#
# 5740 /content/gdrive/MyDrive/images/3103587323_7f093d5b90.jpg
# img_name: /content/gdrive/MyDrive/images/3103587323_7f093d5b90.jpg
# BLEU-1 score: 44.44444444444444
# BLEU-2 score: 33.333333333333336
# BLEU-3 score: 28.853455719062136
# BLEU-4 score: 35.49481056010053
# Real Caption: young girl pulling the tail of an alligator <unk>
# Predicted Caption: little boy sits on the tail of fake alligator
#
#
# 4108 /content/gdrive/MyDrive/images/3159447439_c1496cbaea.jpg
# img_name: /content/gdrive/MyDrive/images/3159447439_c1496cbaea.jpg
# BLEU-1 score: 42.857142857142854
# BLEU-2 score: 65.46536707079771
# BLEU-3 score: 77.55449324140362
# BLEU-4 score: 80.91067115702212
# Real Caption: two brown dogs run through the grass
# Predicted Caption: two dogs are running through grassy area
#
#
# 2138 /content/gdrive/MyDrive/images/1348891916_ebd4413033.jpg
# img_name: /content/gdrive/MyDrive/images/1348891916_ebd4413033.jpg
# BLEU-1 score: 37.5
# BLEU-2 score: 61.237243569579455
# BLEU-3 score: 74.5091107671223
# BLEU-4 score: 78.25422900366436
# Real Caption: brown dog running through shallow water
# Predicted Caption: the dog runs through the water with stick
#
#
# 5187 /content/gdrive/MyDrive/images/2978409165_acc4f29a40.jpg
# img_name: /content/gdrive/MyDrive/images/2978409165_acc4f29a40.jpg
# BLEU-1 score: 26.959737847033296
# BLEU-2 score: 24.610760938743166
# BLEU-3 score: 22.519794051451818
# BLEU-4 score: 25.267624512808517
# Real Caption: man in blue wetsuit rides wave on white surfboard
# Predicted Caption: man in blue bodysuit surfing
#
#
# 7797 /content/gdrive/MyDrive/images/57422853_b5f6366081.jpg
# img_name: /content/gdrive/MyDrive/images/57422853_b5f6366081.jpg
# BLEU-1 score: 32.749230123119276
# BLEU-2 score: 17.260359801008903
# BLEU-3 score: 32.172613982199174
# BLEU-4 score: 37.592003642100465
# Real Caption: person sticks their head out of tent at the top of mountain
# Predicted Caption: someone is peaking out of dome tent near snowy mountain
#
#
# 5975 /content/gdrive/MyDrive/images/2165677531_e1d5e086f7.jpg
# img_name: /content/gdrive/MyDrive/images/2165677531_e1d5e086f7.jpg
# BLEU-1 score: 7.437672004947659
# BLEU-2 score: 12.882425802602027
# BLEU-3 score: 16.048036399602605
# BLEU-4 score: 16.954225822593184
# Real Caption: blue rally car pulls away from the spectators watching from the side of the track
# Predicted Caption: people on the sidelines of truck
#
#
# 1838 /content/gdrive/MyDrive/images/2261962622_e9318a95eb.jpg
# img_name: /content/gdrive/MyDrive/images/2261962622_e9318a95eb.jpg
# BLEU-1 score: 53.84615384615385
# BLEU-2 score: 29.957234475763904
# BLEU-3 score: 23.631061239083287
# BLEU-4 score: 30.054028093782886
# Real Caption: woman plays video boxing game on big screen
# Predicted Caption: woman watching herself on big screen while she is playing boxing video game
#
#
# 5445 /content/gdrive/MyDrive/images/347543966_b2053ae78c.jpg
# img_name: /content/gdrive/MyDrive/images/347543966_b2053ae78c.jpg
# BLEU-1 score: 54.88116360940264
# BLEU-2 score: 38.806842947616985
# BLEU-3 score: 44.577356656555914
# BLEU-4 score: 46.149373744099286
# Real Caption: three people stand in an outdoor glass structure
# Predicted Caption: three people in glass structure
#
#
# 17 /content/gdrive/MyDrive/images/2874728371_ccd6db87f3.jpg
# img_name: /content/gdrive/MyDrive/images/2874728371_ccd6db87f3.jpg
# BLEU-1 score: 13.381535712974756
# BLEU-2 score: 10.115490187617313
# BLEU-3 score: 19.697837003427995
# BLEU-4 score: 23.26893149242971
# Real Caption: large brown dog has his <unk> on the back of small black dog
# Predicted Caption: two dogs are playing together on the sidewalk
#
#
# 7687 /content/gdrive/MyDrive/images/2782433864_5a0c311d87.jpg
# img_name: /content/gdrive/MyDrive/images/2782433864_5a0c311d87.jpg
# BLEU-1 score: 20.21768865708778
# BLEU-2 score: 35.01806396568502
# BLEU-3 score: 43.623085727489084
# BLEU-4 score: 46.08636396914616
# Real Caption: three small dogs two of which are sniffing noses
# Predicted Caption: three dogs play in the sand
#
#
# 913 /content/gdrive/MyDrive/images/1338523142_57fce8229b.jpg
# img_name: /content/gdrive/MyDrive/images/1338523142_57fce8229b.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: the man climbs through the rocks and snow
# Predicted Caption: hiker walks down rocky path towards land with water
#
#
# 4782 /content/gdrive/MyDrive/images/3710353645_8fbfaa4175.jpg
# img_name: /content/gdrive/MyDrive/images/3710353645_8fbfaa4175.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 15.075567228888179
# BLEU-3 score: 32.133956175406574
# BLEU-4 score: 38.827267775222325
# Real Caption: girl is jumping
# Predicted Caption: girl in pink shirt is jumping through the air over playground equipment
#
#
# 2411 /content/gdrive/MyDrive/images/1479028910_3dab3448c8.jpg
# img_name: /content/gdrive/MyDrive/images/1479028910_3dab3448c8.jpg
# BLEU-1 score: 10.976232721880528
# BLEU-2 score: 24.543602502982406
# BLEU-3 score: 33.86353637247854
# BLEU-4 score: 36.70124608961283
# Real Caption: boy skateboards and does jump over another skateboard
# Predicted Caption: skateboarder jumps over homemade ramp
#
#
# 639 /content/gdrive/MyDrive/images/3636126441_5617c89aaa.jpg
# img_name: /content/gdrive/MyDrive/images/3636126441_5617c89aaa.jpg
# BLEU-1 score: 7.1428571428571415
# BLEU-2 score: 26.726124191242434
# BLEU-3 score: 45.30661222656875
# BLEU-4 score: 51.697315395717055
# Real Caption: the skateboarder does jump down stairs
# Predicted Caption: boy in green shirt is jumping off skateboard at the top of small staircase
#
#
# 411 /content/gdrive/MyDrive/images/2432709509_2a4d0c833f.jpg
# img_name: /content/gdrive/MyDrive/images/2432709509_2a4d0c833f.jpg
# BLEU-1 score: 7.6923076923076925
# BLEU-2 score: 27.735009811261456
# BLEU-3 score: 46.32516707503672
# BLEU-4 score: 52.66403878479265
# Real Caption: baby by <unk> drain cries
# Predicted Caption: young boy is sitting on the grass with drain pipe in the background
#
#
# 7556 /content/gdrive/MyDrive/images/2824922268_3fafb64683.jpg
# img_name: /content/gdrive/MyDrive/images/2824922268_3fafb64683.jpg
# BLEU-1 score: 36.36363636363637
# BLEU-2 score: 26.967994498529684
# BLEU-3 score: 23.563317641070423
# BLEU-4 score: 29.98221389342337
# Real Caption: brown dog is splashing water in yard
# Predicted Caption: brown dog is jumping up to catch frisbee in its mouth
#
#
# 2510 /content/gdrive/MyDrive/images/3613375729_d0b3c41556.jpg
# img_name: /content/gdrive/MyDrive/images/3613375729_d0b3c41556.jpg
# BLEU-1 score: 22.22222222222222
# BLEU-2 score: 16.666666666666668
# BLEU-3 score: 34.127875184653654
# BLEU-4 score: 40.8248290463863
# Real Caption: person is riding red motorcycle around track
# Predicted Caption: man in blue and white uniform rides red motorcycle
#
#
# 6524 /content/gdrive/MyDrive/images/2310108346_e82d209ccd.jpg
# img_name: /content/gdrive/MyDrive/images/2310108346_e82d209ccd.jpg
# BLEU-1 score: 15.163266492815836
# BLEU-2 score: 30.326532985631673
# BLEU-3 score: 40.01610018085611
# BLEU-4 score: 42.88819424803535
# Real Caption: woman with sweater sits on sea wall and looks to the sea
# Predicted Caption: man is sitting on dock in the water
#
#
# 1988 /content/gdrive/MyDrive/images/3636543173_15f56515e5.jpg
# img_name: /content/gdrive/MyDrive/images/3636543173_15f56515e5.jpg
# BLEU-1 score: 12.197089792217975
# BLEU-2 score: 7.422912461237536
# BLEU-3 score: 14.655430824153672
# BLEU-4 score: 17.372193280209608
# Real Caption: the man wearing the brown jacket is holding cigarette and the man behind him is holding can of beer
# Predicted Caption: man in white shirt is holding toddler with red hair
#
#
# 2820 /content/gdrive/MyDrive/images/394463341_5311c53783.jpg
# img_name: /content/gdrive/MyDrive/images/394463341_5311c53783.jpg
# BLEU-1 score: 13.381535712974756
# BLEU-2 score: 26.763071425949512
# BLEU-3 score: 35.31408446312039
# BLEU-4 score: 37.84869858133765
# Real Caption: dog owner watches their dog climb over the rocky <unk> of walking path
# Predicted Caption: large black dog is digging under the yard
#
#
# 6186 /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# img_name: /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# BLEU-1 score: 28.57142857142857
# BLEU-2 score: 21.82178902359924
# BLEU-3 score: 40.11753235797364
# BLEU-4 score: 46.71379777282001
# Real Caption: three dogs racing <unk> around racetrack
# Predicted Caption: three dogs are making turn in race
#
#
# 7213 /content/gdrive/MyDrive/images/997722733_0cb5439472.jpg
# img_name: /content/gdrive/MyDrive/images/997722733_0cb5439472.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 50.0
# BLEU-3 score: 65.9753955386447
# BLEU-4 score: 70.71067811865476
# Real Caption: man in pink shirt climbs rock face
# Predicted Caption: man is climbing cliff high in the air
#
#
# 5635 /content/gdrive/MyDrive/images/3417662443_2eaea88977.jpg
# img_name: /content/gdrive/MyDrive/images/3417662443_2eaea88977.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: person wearing spiderman print outfit looks up with hood on his face
# Predicted Caption: man in red hooded coat smokes cigarette
#
#
# 5233 /content/gdrive/MyDrive/images/408627152_1feaa4b94e.jpg
# img_name: /content/gdrive/MyDrive/images/408627152_1feaa4b94e.jpg
# BLEU-1 score: 21.052631578947366
# BLEU-2 score: 10.814761408717501
# BLEU-3 score: 26.327532986605316
# BLEU-4 score: 32.88580454955831
# Real Caption: white dog in life jacket looks at man in boat
# Predicted Caption: white dog with life vest on the beach the man holding black dog and white dog on to right
#
#
# 4532 /content/gdrive/MyDrive/images/2222186636_85e03e0b75.jpg
# img_name: /content/gdrive/MyDrive/images/2222186636_85e03e0b75.jpg
# BLEU-1 score: 20.0
# BLEU-2 score: 14.9071198499986
# BLEU-3 score: 31.918042293931485
# BLEU-4 score: 38.60973950960897
# Real Caption: group of people standing in bar
# Predicted Caption: group of men stand at the counter of busy establishment
#
#
# 6666 /content/gdrive/MyDrive/images/3218481970_1fa627b3da.jpg
# img_name: /content/gdrive/MyDrive/images/3218481970_1fa627b3da.jpg
# BLEU-1 score: 39.77063630286087
# BLEU-2 score: 29.82797722714566
# BLEU-3 score: 46.288414438794135
# BLEU-4 score: 51.663572044423724
# Real Caption: the basketball player is dropping the basketball into the net
# Predicted Caption: basketball player in white leaps up at the net
#
#
# 4957 /content/gdrive/MyDrive/images/2491343114_a3e35a2a3a.jpg
# img_name: /content/gdrive/MyDrive/images/2491343114_a3e35a2a3a.jpg
# BLEU-1 score: 14.795817836496388
# BLEU-2 score: 9.550659345711528
# BLEU-3 score: 13.957739963868443
# BLEU-4 score: 15.346542276007952
# Real Caption: skinny brown dog runs across the wet sand with his mouth open
# Predicted Caption: dog runs on the beach
#
#
# 4977 /content/gdrive/MyDrive/images/2925737498_57585a7ed9.jpg
# img_name: /content/gdrive/MyDrive/images/2925737498_57585a7ed9.jpg
# BLEU-1 score: 16.374615061559638
# BLEU-2 score: 36.61475238303926
# BLEU-3 score: 50.518459909936965
# BLEU-4 score: 54.751825350694524
# Real Caption: man wearing jeans jacket is smiling
# Predicted Caption: boy in jacket and sunglasses
#
#
# 1214 /content/gdrive/MyDrive/images/110595925_f3395c8bd6.jpg
# img_name: /content/gdrive/MyDrive/images/110595925_f3395c8bd6.jpg
# BLEU-1 score: 9.09090909090909
# BLEU-2 score: 30.15113445777636
# BLEU-3 score: 48.70596972258285
# BLEU-4 score: 54.91004867761124
# Real Caption: man on mountain bike is pedaling up hill
# Predicted Caption: man in aerodynamic gear riding bicycle down road around sharp curve
#
#
# 3024 /content/gdrive/MyDrive/images/328916930_e4d4be1730.jpg
# img_name: /content/gdrive/MyDrive/images/328916930_e4d4be1730.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: mother is <unk> her daughter on the sidewalk
# Predicted Caption: two young women in brightly colored shirts holding bags
#
#
# 7008 /content/gdrive/MyDrive/images/2120383553_5825333a3f.jpg
# img_name: /content/gdrive/MyDrive/images/2120383553_5825333a3f.jpg
# BLEU-1 score: 11.76470588235294
# BLEU-2 score: 34.29971702850177
# BLEU-3 score: 52.622844783925785
# BLEU-4 score: 58.56596027429395
# Real Caption: girl <unk> out wet shirt
# Predicted Caption: the little girl is wearing green striped shirt and is spinning green hula hoop around her neck
#
#
# 5617 /content/gdrive/MyDrive/images/1413956047_c826f90c8b.jpg
# img_name: /content/gdrive/MyDrive/images/1413956047_c826f90c8b.jpg
# BLEU-1 score: 37.1519099892935
# BLEU-2 score: 56.75047991270782
# BLEU-3 score: 67.23027621729763
# BLEU-4 score: 70.13967267997694
# Real Caption: these three young men are standing on mountaintop
# Predicted Caption: three people are walking on rocky slope
#
#
# 1632 /content/gdrive/MyDrive/images/3557295488_600d387347.jpg
# img_name: /content/gdrive/MyDrive/images/3557295488_600d387347.jpg
# BLEU-1 score: 4.555807961771006
# BLEU-2 score: 12.05353488781414
# BLEU-3 score: 17.78828328977971
# BLEU-4 score: 19.60599733412503
# Real Caption: man in red uniform swings while another in blue uniform jumps and others look on
# Predicted Caption: two men are playing in soccer game
#
#
# 3239 /content/gdrive/MyDrive/images/308014594_f1d5e75507.jpg
# img_name: /content/gdrive/MyDrive/images/308014594_f1d5e75507.jpg
# BLEU-1 score: 28.2160574963538
# BLEU-2 score: 48.871645172969465
# BLEU-3 score: 60.88092046187942
# BLEU-4 score: 64.31870218238024
# Real Caption: two japanese girls are wearing traditional dress
# Predicted Caption: two women in elaborate japanese dresses
#
#
# 2367 /content/gdrive/MyDrive/images/487074671_66db20bf47.jpg
# img_name: /content/gdrive/MyDrive/images/487074671_66db20bf47.jpg
# BLEU-1 score: 14.248453076221212
# BLEU-2 score: 30.22553337484303
# BLEU-3 score: 40.83348773238403
# BLEU-4 score: 44.02274324685413
# Real Caption: man in brown jacket and blue cap is washing black jacket in fountain
# Predicted Caption: the man is lying on the wet bench outside
#
#
# 4064 /content/gdrive/MyDrive/images/445861800_75fc6a8c16.jpg
# img_name: /content/gdrive/MyDrive/images/445861800_75fc6a8c16.jpg
# BLEU-1 score: 17.182231969774307
# BLEU-2 score: 34.364463939548614
# BLEU-3 score: 45.34418201770425
# BLEU-4 score: 48.59869096699081
# Real Caption: three people wearing winter clothes standing on the sidewalk near street
# Predicted Caption: man walks down the street with white dog
#
#
# 2665 /content/gdrive/MyDrive/images/2747640247_b54bfa6886.jpg
# img_name: /content/gdrive/MyDrive/images/2747640247_b54bfa6886.jpg
# BLEU-1 score: 44.44444444444444
# BLEU-2 score: 66.66666666666666
# BLEU-3 score: 78.40526816831157
# BLEU-4 score: 81.6496580927726
# Real Caption: girl swings on tree over breaking waves
# Predicted Caption: girl is swinging over small waves on the water
#
#
# 1770 /content/gdrive/MyDrive/images/3533470072_87a5b595ba.jpg
# img_name: /content/gdrive/MyDrive/images/3533470072_87a5b595ba.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: <unk> young ladies give the piece sign with their fingers to the camera
# Predicted Caption: two girls are standing in crowd and smiling
#
#
# 7867 /content/gdrive/MyDrive/images/487487795_54705c406e.jpg
# img_name: /content/gdrive/MyDrive/images/487487795_54705c406e.jpg
# BLEU-1 score: 18.18740767186928
# BLEU-2 score: 11.341841376953123
# BLEU-3 score: 19.226895958571077
# BLEU-4 score: 21.938936848339242
# Real Caption: two dogs on hind legs with faces near each other on grassy field
# Predicted Caption: two dogs are playing in grassy area
#
#
# 1535 /content/gdrive/MyDrive/images/2940366012_1ef8ab334e.jpg
# img_name: /content/gdrive/MyDrive/images/2940366012_1ef8ab334e.jpg
# BLEU-1 score: 21.021682352653848
# BLEU-2 score: 27.809071822658638
# BLEU-3 score: 31.102414399847017
# BLEU-4 score: 31.984974287337113
# Real Caption: man in red shirt sits on his dirt bike and points at the camera
# Predicted Caption: man on bike is pointing at you
#
#
# 3575 /content/gdrive/MyDrive/images/3590739067_58baffb3a7.jpg
# img_name: /content/gdrive/MyDrive/images/3590739067_58baffb3a7.jpg
# BLEU-1 score: 14.285714285714285
# BLEU-2 score: 37.79644730092272
# BLEU-3 score: 55.778982530324605
# BLEU-4 score: 61.47881529512643
# Real Caption: woman with guitar sings in front of building and grass
# Predicted Caption: the girl has on its face and has her hair holding in its mouth
#
#
# 731 /content/gdrive/MyDrive/images/3244910944_612b8ce98f.jpg
# img_name: /content/gdrive/MyDrive/images/3244910944_612b8ce98f.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: an individual adorned in white rides motorcycle
# Predicted Caption: the motocross rider is on bike and on its side after taking on the track
#
#
# 3917 /content/gdrive/MyDrive/images/2876993733_cb26107d18.jpg
# img_name: /content/gdrive/MyDrive/images/2876993733_cb26107d18.jpg
# BLEU-1 score: 30.0
# BLEU-2 score: 18.257418583505533
# BLEU-3 score: 36.04654325043383
# BLEU-4 score: 42.728700639623405
# Real Caption: two lonely fans in green ponchos sit in stadium
# Predicted Caption: two boys with green wait in green bleachers behind them
#
#
# 2975 /content/gdrive/MyDrive/images/3224227640_31865b3651.jpg
# img_name: /content/gdrive/MyDrive/images/3224227640_31865b3651.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 18.898223650461357
# BLEU-3 score: 36.80040435181319
# BLEU-4 score: 43.47208719449914
# Real Caption: two dogs paying attention to each other
# Predicted Caption: two dogs are playing together on the grass
#
#
# 2731 /content/gdrive/MyDrive/images/3268443910_b36dbc1e5c.jpg
# img_name: /content/gdrive/MyDrive/images/3268443910_b36dbc1e5c.jpg
# BLEU-1 score: 45.45454545454545
# BLEU-2 score: 36.92744729379982
# BLEU-3 score: 35.03045820726322
# BLEU-4 score: 24.808415001701817
# Real Caption: man in an orange shirt playing tennis
# Predicted Caption: man in an orange wristbands hits tennis ball with his racquet
#
#
# 6706 /content/gdrive/MyDrive/images/3211316116_a2462e327d.jpg
# img_name: /content/gdrive/MyDrive/images/3211316116_a2462e327d.jpg
# BLEU-1 score: 25.773347954661457
# BLEU-2 score: 15.90765571657157
# BLEU-3 score: 28.564033753559343
# BLEU-4 score: 33.0653311259657
# Real Caption: surfer in yellow shirt is riding wave that is reflecting sunlight
# Predicted Caption: the man is riding small wave on beach
#
#
# 7315 /content/gdrive/MyDrive/images/2412390588_a89cab30f4.jpg
# img_name: /content/gdrive/MyDrive/images/2412390588_a89cab30f4.jpg
# BLEU-1 score: 49.53587998572467
# BLEU-2 score: 37.833653275138545
# BLEU-3 score: 32.52513732152583
# BLEU-4 score: 38.29795673743804
# Real Caption: boy in red jacket points at red tulips
# Predicted Caption: boy in red is pointing to red
#
#
# 6186 /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# img_name: /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# BLEU-1 score: 28.57142857142857
# BLEU-2 score: 21.82178902359924
# BLEU-3 score: 40.11753235797364
# BLEU-4 score: 46.71379777282001
# Real Caption: three dogs racing <unk> around racetrack
# Predicted Caption: three dogs are making turn in race
#
#
# 7374 /content/gdrive/MyDrive/images/3683185795_704f445bf4.jpg
# img_name: /content/gdrive/MyDrive/images/3683185795_704f445bf4.jpg
# BLEU-1 score: 12.383969996431167
# BLEU-2 score: 32.76490485424231
# BLEU-3 score: 48.35356722608987
# BLEU-4 score: 53.294626282168544
# Real Caption: boy and girl look on puppy climbs tree
# Predicted Caption: two children are playing on the woods
#
#
# 7661 /content/gdrive/MyDrive/images/3641022607_e7a5455d6c.jpg
# img_name: /content/gdrive/MyDrive/images/3641022607_e7a5455d6c.jpg
# BLEU-1 score: 32.928698165641585
# BLEU-2 score: 30.059651291001472
# BLEU-3 score: 27.50573856764223
# BLEU-4 score: 30.86194627209984
# Real Caption: kite surfer begins to fall in the ocean
# Predicted Caption: man windsurfs in the ocean
#
#
# 2196 /content/gdrive/MyDrive/images/3215847501_c723905ba4.jpg
# img_name: /content/gdrive/MyDrive/images/3215847501_c723905ba4.jpg
# BLEU-1 score: 24.561922592339457
# BLEU-2 score: 14.947910066133426
# BLEU-3 score: 29.512413501285735
# BLEU-4 score: 34.98330125272251
# Real Caption: group of climbers in silhouette stare towards the sun over the mountaintops
# Predicted Caption: group of people are standing on hill above the clouds
#
#
# 5653 /content/gdrive/MyDrive/images/395461421_c586b136de.jpg
# img_name: /content/gdrive/MyDrive/images/395461421_c586b136de.jpg
# BLEU-1 score: 12.500000000000004
# BLEU-2 score: 35.35533905932738
# BLEU-3 score: 53.588673126814655
# BLEU-4 score: 59.46035575013605
# Real Caption: four boys running and jumping
# Predicted Caption: the young boys are playing in the street
#
#
# 4639 /content/gdrive/MyDrive/images/957682378_46c3b07bcd.jpg
# img_name: /content/gdrive/MyDrive/images/957682378_46c3b07bcd.jpg
# BLEU-1 score: 41.50457801283011
# BLEU-2 score: 27.531022470118398
# BLEU-3 score: 44.47345584091259
# BLEU-4 score: 50.138404778620725
# Real Caption: brown dog and black dog run into each other in the grass
# Predicted Caption: dark brown dog is playing with black dog on green grass
#
#
# 1866 /content/gdrive/MyDrive/images/3468023754_8a07d4c56e.jpg
# img_name: /content/gdrive/MyDrive/images/3468023754_8a07d4c56e.jpg
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: four children hold rolled up magazines to their eyes
# Predicted Caption: two young children are looking into an indoor fountain
#
#
# 38 /content/gdrive/MyDrive/images/661757041_61e131e913.jpg
# img_name: /content/gdrive/MyDrive/images/661757041_61e131e913.jpg
# BLEU-1 score: 37.5
# BLEU-2 score: 23.145502494313785
# BLEU-3 score: 41.560423878293356
# BLEU-4 score: 48.10977290978807
# Real Caption: dog catching red ball in field
# Predicted Caption: small dog jumps up to catch red ball
#
#
# 738 /content/gdrive/MyDrive/images/1620397000_3883e3ecd3.jpg
# img_name: /content/gdrive/MyDrive/images/1620397000_3883e3ecd3.jpg
# BLEU-1 score: 24.249876895825707
# BLEU-2 score: 32.0795717951429
# BLEU-3 score: 35.87865650838505
# BLEU-4 score: 36.89674670049219
# Real Caption: black and white spotted dog is jumping over the small stream of water
# Predicted Caption: dog with black spots jumps over stream
#
#
# 4864 /content/gdrive/MyDrive/images/3295418287_5d590dac43.jpg
# img_name: /content/gdrive/MyDrive/images/3295418287_5d590dac43.jpg
# BLEU-1 score: 22.22222222222222
# BLEU-2 score: 47.14045207910317
# BLEU-3 score: 63.684866956664344
# BLEU-4 score: 68.65890479690393
# Real Caption: men smiles in front of chinese market
# Predicted Caption: people gather in line facing the heads of people
#
#
# 5659 /content/gdrive/MyDrive/images/3436395540_63bc8f2fe0.jpg
# img_name: /content/gdrive/MyDrive/images/3436395540_63bc8f2fe0.jpg
# BLEU-1 score: 33.51600230178197
# BLEU-2 score: 15.799595003902642
# BLEU-3 score: 28.16439688882424
# BLEU-4 score: 32.54348667607771
# Real Caption: three dogs in colored sweaters run across grass with ladder and hand in background
# Predicted Caption: three dogs run through the grass while wearing colored shirts
#
#
# 3590 /content/gdrive/MyDrive/images/3361990489_92244a58ef.jpg
# img_name: /content/gdrive/MyDrive/images/3361990489_92244a58ef.jpg
# BLEU-1 score: 27.27272727272727
# BLEU-2 score: 16.514456476895408
# BLEU-3 score: 33.94052617741644
# BLEU-4 score: 40.637982820134425
# Real Caption: girl posing on tree
# Predicted Caption: young girl in jeans is standing on tree limb in park
#
#
# 1573 /content/gdrive/MyDrive/images/1143373711_2e90b7b799.jpg
# img_name: /content/gdrive/MyDrive/images/1143373711_2e90b7b799.jpg
# BLEU-1 score: 26.691246763893595
# BLEU-2 score: 16.34498379256302
# BLEU-3 score: 30.862190141752656
# BLEU-4 score: 36.17739608204856
# Real Caption: man in blue and white biking gear rides down busy street
# Predicted Caption: man in orange is on bicycle in busy race
#
#
# 834 /content/gdrive/MyDrive/images/3101378069_f8caa14c0a.jpg
# img_name: /content/gdrive/MyDrive/images/3101378069_f8caa14c0a.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 50.0
# BLEU-3 score: 65.9753955386447
# BLEU-4 score: 70.71067811865476
# Real Caption: lady rows canoe filled with things
# Predicted Caption: an asian woman rows boat loaded with supplies
#
#
# 5318 /content/gdrive/MyDrive/images/3349194268_0ee555c9a2.jpg
# img_name: /content/gdrive/MyDrive/images/3349194268_0ee555c9a2.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: <unk> girls pose behind yellow wildflowers
# Predicted Caption: the girl is holding onto in the grass
#
#
# 7866 /content/gdrive/MyDrive/images/3293596075_973b0bfd08.jpg
# img_name: /content/gdrive/MyDrive/images/3293596075_973b0bfd08.jpg
# BLEU-1 score: 26.691246763893595
# BLEU-2 score: 46.230595512422084
# BLEU-3 score: 57.59088318667449
# BLEU-4 score: 60.84288535721682
# Real Caption: dog up to its belly in the snow attempts to move
# Predicted Caption: dog is running through snow next to some plants
#
#
# 6911 /content/gdrive/MyDrive/images/3053813297_7ce5f87710.jpg
# img_name: /content/gdrive/MyDrive/images/3053813297_7ce5f87710.jpg
# BLEU-1 score: 41.66666666666667
# BLEU-2 score: 19.462473604038074
# BLEU-3 score: 37.45577796875112
# BLEU-4 score: 44.11629359322706
# Real Caption: people sitting in chairs while dog lies in grass
# Predicted Caption: some people in lawn chairs are sitting in front of white tents
#
#
# 6478 /content/gdrive/MyDrive/images/3245250964_9d3e37111e.jpg
# img_name: /content/gdrive/MyDrive/images/3245250964_9d3e37111e.jpg
# BLEU-1 score: 20.189651799465537
# BLEU-2 score: 20.189651799465537
# BLEU-3 score: 20.189651799465537
# BLEU-4 score: 20.189651799465537
# Real Caption: two men are playing basketball and one is trying to block the other
# Predicted Caption: two men are playing basketball
#
#
# 7449 /content/gdrive/MyDrive/images/3650111717_346804ec2f.jpg
# img_name: /content/gdrive/MyDrive/images/3650111717_346804ec2f.jpg
# BLEU-1 score: 16.666666666666668
# BLEU-2 score: 40.8248290463863
# BLEU-3 score: 58.419068106786554
# BLEU-4 score: 63.89431042462724
# Real Caption: small wet dog leaps to catch stick
# Predicted Caption: the dog is shaking its wet yard with something above its head
#
#
# 3370 /content/gdrive/MyDrive/images/3376435746_1593d9b243.jpg
# img_name: /content/gdrive/MyDrive/images/3376435746_1593d9b243.jpg
# BLEU-1 score: 14.486606950235942
# BLEU-2 score: 25.091539267089075
# BLEU-3 score: 31.257306787590522
# BLEU-4 score: 33.02232277439296
# Real Caption: person in yellow slicker is driving motorboat next to the beach
# Predicted Caption: person on boat by the shore
#
#
# 7073 /content/gdrive/MyDrive/images/47870024_73a4481f7d.jpg
# img_name: /content/gdrive/MyDrive/images/47870024_73a4481f7d.jpg
# BLEU-1 score: 14.285714285714285
# BLEU-2 score: 10.482848367219184
# BLEU-3 score: 25.83970684992841
# BLEU-4 score: 32.37722713145643
# Real Caption: boy wearing helmet rides scooter in suburban neighborhood
# Predicted Caption: young boy wearing an orange uniform is jumping over low seat on playground equipment
#
#
# 7285 /content/gdrive/MyDrive/images/701816897_221bbe761a.jpg
# img_name: /content/gdrive/MyDrive/images/701816897_221bbe761a.jpg
# BLEU-1 score: 21.162043122265352
# BLEU-2 score: 42.324086244530704
# BLEU-3 score: 55.84696661589249
# BLEU-4 score: 59.855296782063874
# Real Caption: young girl jumping into pool while another stands on the side with an innertube
# Predicted Caption: two young girls making splash as they are playing in the pool
#
#
# 4915 /content/gdrive/MyDrive/images/3523559027_a65619a34b.jpg
# img_name: /content/gdrive/MyDrive/images/3523559027_a65619a34b.jpg
# BLEU-1 score: 37.5
# BLEU-2 score: 23.145502494313785
# BLEU-3 score: 41.560423878293356
# BLEU-4 score: 48.10977290978807
# Real Caption: many people in formation on field
# Predicted Caption: group of people are playing soccer on field
#
#
# 682 /content/gdrive/MyDrive/images/2858759108_6e697c5f3e.jpg
# img_name: /content/gdrive/MyDrive/images/2858759108_6e697c5f3e.jpg
# BLEU-1 score: 18.181818181818183
# BLEU-2 score: 42.640143271122085
# BLEU-3 score: 59.964082520504526
# BLEU-4 score: 65.29942057256105
# Real Caption: lean dog races along dirt track
# Predicted Caption: white dog wearing yellow and black jacket is running on track
#
#
# 1234 /content/gdrive/MyDrive/images/2975807155_5a8610c297.jpg
# img_name: /content/gdrive/MyDrive/images/2975807155_5a8610c297.jpg
# BLEU-1 score: 10.976232721880528
# BLEU-2 score: 24.543602502982406
# BLEU-3 score: 33.86353637247854
# BLEU-4 score: 36.70124608961283
# Real Caption: the runner <unk> batman uniform for the race
# Predicted Caption: man in batman suit running
#
#
# 309 /content/gdrive/MyDrive/images/2698119128_62b4741043.jpg
# img_name: /content/gdrive/MyDrive/images/2698119128_62b4741043.jpg
# BLEU-1 score: 22.07276647028654
# BLEU-2 score: 14.247909490690875
# BLEU-3 score: 20.822501201353518
# BLEU-4 score: 22.894350790744532
# Real Caption: young girl in red bathing suit is swimming in pool
# Predicted Caption: girl doing handstand in pool
#
#
# 7911 /content/gdrive/MyDrive/images/2971211296_2587c3924d.jpg
# img_name: /content/gdrive/MyDrive/images/2971211296_2587c3924d.jpg
# BLEU-1 score: 54.54545454545454
# BLEU-2 score: 40.45199174779452
# BLEU-3 score: 36.99986946208831
# BLEU-4 score: 25.96535889340338
# Real Caption: the boy in the red jersey runs with the football
# Predicted Caption: the boy in the blue jersey is running through the grass
#
#
# 2831 /content/gdrive/MyDrive/images/637342973_89f6fac1f7.jpg
# img_name: /content/gdrive/MyDrive/images/637342973_89f6fac1f7.jpg
# BLEU-1 score: 35.588329018524796
# BLEU-2 score: 53.38249352778719
# BLEU-3 score: 62.78203080808969
# BLEU-4 score: 65.37993517025207
# Real Caption: pink ball is being held up before three dogs on beach
# Predicted Caption: two dogs are playing with ball on the beach
#
#
# 4204 /content/gdrive/MyDrive/images/3593392955_a4125087f6.jpg
# img_name: /content/gdrive/MyDrive/images/3593392955_a4125087f6.jpg
# BLEU-1 score: 63.63636363636363
# BLEU-2 score: 56.40760748177662
# BLEU-3 score: 51.01128119150891
# BLEU-4 score: 40.352786374639905
# Real Caption: two dogs run down dirt path in the forest
# Predicted Caption: two dogs are running away down dirt path in the woods
#
#
# 600 /content/gdrive/MyDrive/images/3174417550_d2e6100278.jpg
# img_name: /content/gdrive/MyDrive/images/3174417550_d2e6100278.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: snowboarder rides his board off graffiti covered wall at night
# Predicted Caption: man jumps while riding skateboard
#
#
# 7041 /content/gdrive/MyDrive/images/537559285_29be110134.jpg
# img_name: /content/gdrive/MyDrive/images/537559285_29be110134.jpg
# BLEU-1 score: 14.108028748176901
# BLEU-2 score: 34.55747170954952
# BLEU-3 score: 49.45067353753494
# BLEU-4 score: 54.085366098934806
# Real Caption: brown and white sheltie leaping over rail
# Predicted Caption: tan dog is jumping over hurdle
#
#
# 6862 /content/gdrive/MyDrive/images/2406591500_403f145905.jpg
# img_name: /content/gdrive/MyDrive/images/2406591500_403f145905.jpg
# BLEU-1 score: 9.306272250443651
# BLEU-2 score: 24.622082007735305
# BLEU-3 score: 36.336607809595876
# BLEU-4 score: 40.04970149398301
# Real Caption: two boys are running on path <unk> green leafy trees
# Predicted Caption: young boy is walking on the sidewalk
#
#
# 3133 /content/gdrive/MyDrive/images/642987597_03b21a1437.jpg
# img_name: /content/gdrive/MyDrive/images/642987597_03b21a1437.jpg
# BLEU-1 score: 33.33333333333333
# BLEU-2 score: 20.412414523193153
# BLEU-3 score: 38.54221125344267
# BLEU-4 score: 45.180100180492246
# Real Caption: girl in tree smiles
# Predicted Caption: young girl is putting branch from tree in tree
#
#
# 874 /content/gdrive/MyDrive/images/3272002857_ace031f564.jpg
# img_name: /content/gdrive/MyDrive/images/3272002857_ace031f564.jpg
# BLEU-1 score: 47.76875403825262
# BLEU-2 score: 45.317419124773295
# BLEU-3 score: 44.21240823231761
# BLEU-4 score: 36.409302398068725
# Real Caption: woman riding large brown horse on the beach
# Predicted Caption: person on horse on the beach
#
#
# 3062 /content/gdrive/MyDrive/images/519167484_ee03e2a91e.jpg
# img_name: /content/gdrive/MyDrive/images/519167484_ee03e2a91e.jpg
# BLEU-1 score: 15.570161195729886
# BLEU-2 score: 22.019533131336495
# BLEU-3 score: 25.29380148576894
# BLEU-4 score: 26.185785468823504
# Real Caption: blond haired girl in pink dress with blue striped swinging around her neck
# Predicted Caption: blond girl paying with hula hoop
#
#
# 7094 /content/gdrive/MyDrive/images/2851304910_b5721199bc.jpg
# img_name: /content/gdrive/MyDrive/images/2851304910_b5721199bc.jpg
# BLEU-1 score: 16.666666666666668
# BLEU-2 score: 40.8248290463863
# BLEU-3 score: 58.419068106786554
# BLEU-4 score: 63.89431042462724
# Real Caption: photographer looks over the hills
# Predicted Caption: woman takes picture during the day
#
#
# 935 /content/gdrive/MyDrive/images/3425061393_d093edb8da.jpg
# img_name: /content/gdrive/MyDrive/images/3425061393_d093edb8da.jpg
# BLEU-1 score: 29.632728827268718
# BLEU-2 score: 15.617819396716564
# BLEU-3 score: 29.110984967120707
# BLEU-4 score: 34.01465151431657
# Real Caption: tennis player with green green headband on is ready to hit the ball
# Predicted Caption: the tennis player wearing the match is swinging his racquet
#
#
# 2750 /content/gdrive/MyDrive/images/3261666285_86fceb762d.jpg
# img_name: /content/gdrive/MyDrive/images/3261666285_86fceb762d.jpg
# BLEU-1 score: 7.581633246407919
# BLEU-2 score: 21.444097124017674
# BLEU-3 score: 32.503173264731565
# BLEU-4 score: 36.06452879987789
# Real Caption: guy in black uniform dribbling basketball away from guy in white uniform
# Predicted Caption: two teams of players playing basketball on court
#
#
# 2317 /content/gdrive/MyDrive/images/2307807200_91fa29cba1.jpg
# img_name: /content/gdrive/MyDrive/images/2307807200_91fa29cba1.jpg
# BLEU-1 score: 13.333333333333334
# BLEU-2 score: 36.51483716701108
# BLEU-3 score: 54.63634277011612
# BLEU-4 score: 60.42750794713536
# Real Caption: an elderly woman is standing by the window of grey stone building
# Predicted Caption: woman in red jacket with red purse and red scarf on sitting on the sidewalk
#
#
# 3112 /content/gdrive/MyDrive/images/118187095_d422383c81.jpg
# img_name: /content/gdrive/MyDrive/images/118187095_d422383c81.jpg
# BLEU-1 score: 23.809523809523807
# BLEU-2 score: 15.430334996209194
# BLEU-3 score: 32.585561793662905
# BLEU-4 score: 39.281465090051306
# Real Caption: twin boys being pushed in small car shaped strollers in parade
# Predicted Caption: two young children ride in small child and watches in the back while being pushed on big seat of plastic ride
#
#
# 2646 /content/gdrive/MyDrive/images/3433982387_3fa993cf5a.jpg
# img_name: /content/gdrive/MyDrive/images/3433982387_3fa993cf5a.jpg
# BLEU-1 score: 11.847987712695618
# BLEU-2 score: 18.09810017544479
# BLEU-3 score: 21.440175936397996
# BLEU-4 score: 22.36800154620159
# Real Caption: two little girls and an adult watch bubbles float through the air in front of them
# Predicted Caption: two young girls play together in mall
#
#
# 4992 /content/gdrive/MyDrive/images/2925577165_b83d31a7f6.jpg
# img_name: /content/gdrive/MyDrive/images/2925577165_b83d31a7f6.jpg
# BLEU-1 score: 30.0
# BLEU-2 score: 18.257418583505533
# BLEU-3 score: 36.04654325043383
# BLEU-4 score: 42.728700639623405
# Real Caption: minivan drives through deep puddle of water on the road
# Predicted Caption: minivan drives down wet urban street at night splashing water
#
#
# 566 /content/gdrive/MyDrive/images/950273886_88c324e663.jpg
# img_name: /content/gdrive/MyDrive/images/950273886_88c324e663.jpg
# BLEU-1 score: 43.90493088752211
# BLEU-2 score: 34.70989552921196
# BLEU-3 score: 29.985060665861457
# BLEU-4 score: 33.16331950155214
# Real Caption: man in red shirt attempts to climb rock
# Predicted Caption: man in red rock climbing
#
#
# 172 /content/gdrive/MyDrive/images/3404906655_bc51c69c1e.jpg
# img_name: /content/gdrive/MyDrive/images/3404906655_bc51c69c1e.jpg
# BLEU-1 score: 26.666666666666668
# BLEU-2 score: 51.63977794943222
# BLEU-3 score: 67.26522816702636
# BLEU-4 score: 71.86082239261684
# Real Caption: team of dogs pulling man on sled
# Predicted Caption: man is standing on his sled dogs sled dogs sled dogs sled through the snow
#
#
# 6741 /content/gdrive/MyDrive/images/2856699493_65edef80a1.jpg
# img_name: /content/gdrive/MyDrive/images/2856699493_65edef80a1.jpg
# BLEU-1 score: 9.09090909090909
# BLEU-2 score: 30.15113445777636
# BLEU-3 score: 48.70596972258285
# BLEU-4 score: 54.91004867761124
# Real Caption: man talks to woman wearing backpack
# ...
# img_name: /content/gdrive/MyDrive/images/2622517932_57c52c376f.jpg
# BLEU-1 score: 32.749230123119276
# BLEU-2 score: 51.78107940302672
# BLEU-3 score: 62.19551968890802
# BLEU-4 score: 65.1112602664323
# Real Caption: boy in white shirt is looking through the glass at little creature
# Predicted Caption: the little boy bends down to look at the water
#
#
# 6896 /content/gdrive/MyDrive/images/2899622876_b673b04967.jpg
# img_name: /content/gdrive/MyDrive/images/2899622876_b673b04967.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: speed boat pulling waterskier along jump
# Predicted Caption: water boarder being towed down water rail
#
#
# 2222 /content/gdrive/MyDrive/images/2317714088_bcd081f926.jpg
# img_name: /content/gdrive/MyDrive/images/2317714088_bcd081f926.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: people stand outside house
# Predicted Caption: person has just thrown snowball and hit someone in the back
#
#
# 4820 /content/gdrive/MyDrive/images/3650111717_346804ec2f.jpg
# img_name: /content/gdrive/MyDrive/images/3650111717_346804ec2f.jpg
# BLEU-1 score: 25.960026102380162
# BLEU-2 score: 13.557181477353206
# BLEU-3 score: 27.281748283166724
# BLEU-4 score: 32.493604833572746
# Real Caption: dog is jumping in the air with flowers in his mouth on very windy day
# Predicted Caption: the dog is shaking its wet yard with something above its head
#
#
# 1260 /content/gdrive/MyDrive/images/3223055565_68973f5d20.jpg
# img_name: /content/gdrive/MyDrive/images/3223055565_68973f5d20.jpg
# BLEU-1 score: 40.0
# BLEU-2 score: 21.08185106778919
# BLEU-3 score: 39.29571945508051
# BLEU-4 score: 45.91497693322865
# Real Caption: the man is playing with two dogs in the snow
# Predicted Caption: two dogs play with human and disc on the beach
#
#
# 4734 /content/gdrive/MyDrive/images/3319338707_892ae2a660.jpg
# img_name: /content/gdrive/MyDrive/images/3319338707_892ae2a660.jpg
# BLEU-1 score: 22.744899739223754
# BLEU-2 score: 14.038456897256543
# BLEU-3 score: 25.207671312837952
# BLEU-4 score: 29.180052301598742
# Real Caption: group of adults sit in wood lawn chairs talking surrounded by wilderness
# Predicted Caption: group of people are sitting on lounge chairs
#
#
# 4796 /content/gdrive/MyDrive/images/3255620561_7644747791.jpg
# img_name: /content/gdrive/MyDrive/images/3255620561_7644747791.jpg
# BLEU-1 score: 11.54066216255058
# BLEU-2 score: 8.55878412699898
# BLEU-3 score: 19.075881260604195
# BLEU-4 score: 23.307878468994684
# Real Caption: snow covered wooded area with structure and person in white top and orange pants in midair
# Predicted Caption: the skier wearing orange pants is jumping over the wooden roof
#
#
# 3056 /content/gdrive/MyDrive/images/3384742888_85230c34d5.jpg
# img_name: /content/gdrive/MyDrive/images/3384742888_85230c34d5.jpg
# BLEU-1 score: 10.735389901075512
# BLEU-2 score: 28.4031719055601
# BLEU-3 score: 41.916638802381996
# BLEU-4 score: 46.1999336994571
# Real Caption: rotweiler playfully rolls over int he grass with toy
# Predicted Caption: dog is gnawing up with its ball
#
#
# 4544 /content/gdrive/MyDrive/images/3098336319_a7e5b061d0.jpg
# img_name: /content/gdrive/MyDrive/images/3098336319_a7e5b061d0.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: snowboarder is grinding down long concrete rail
# Predicted Caption: person in red jacket and blue hat doing trick on snowboard
#
#
# 1474 /content/gdrive/MyDrive/images/532396029_ce125bda3f.jpg
# img_name: /content/gdrive/MyDrive/images/532396029_ce125bda3f.jpg
# BLEU-1 score: 30.326532985631673
# BLEU-2 score: 42.88819424803535
# BLEU-3 score: 49.265598181511486
# BLEU-4 score: 51.0029457493824
# Real Caption: little girl finds joy in playing in big <unk> area of mud
# Predicted Caption: young girl in pigtails plays in mud puddle
#
#
# 3919 /content/gdrive/MyDrive/images/2557922709_24d2a9655a.jpg
# img_name: /content/gdrive/MyDrive/images/2557922709_24d2a9655a.jpg
# BLEU-1 score: 39.80729503187718
# BLEU-2 score: 26.703545307500114
# BLEU-3 score: 22.10578856248846
# BLEU-4 score: 26.892274683783953
# Real Caption: girl in glasses is looking over two american flags near wooded area
# Predicted Caption: the girl is blowing on the two american flags
#
#
# 7929 /content/gdrive/MyDrive/images/3335692531_dd4a995f91.jpg
# img_name: /content/gdrive/MyDrive/images/3335692531_dd4a995f91.jpg
# BLEU-1 score: 20.944996871488776
# BLEU-2 score: 37.75913009229282
# BLEU-3 score: 47.796781398466706
# BLEU-4 score: 50.698232714493464
# Real Caption: three large dogs one brown and the others black tussle over red toy in the grass outside building
# Predicted Caption: large black dog is chasing large brown dog with green collar on grass
#
#
# 2644 /content/gdrive/MyDrive/images/2508249781_36e9282423.jpg
# img_name: /content/gdrive/MyDrive/images/2508249781_36e9282423.jpg
# BLEU-1 score: 37.1519099892935
# BLEU-2 score: 27.26204872792376
# BLEU-3 score: 25.297225447382495
# BLEU-4 score: 17.055805176321822
# Real Caption: the woman wearing dress and hat sits on the steps with her head on her hands
# Predicted Caption: woman in yellow jacket is sitting on the steps with an infant beside her
#
#
# 7299 /content/gdrive/MyDrive/images/3440104178_6871a24e13.jpg
# img_name: /content/gdrive/MyDrive/images/3440104178_6871a24e13.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 50.0
# BLEU-3 score: 65.9753955386447
# BLEU-4 score: 70.71067811865476
# Real Caption: white and black dog carrying ball on the beach
# Predicted Caption: small white dog with brown ears is running across the land with ball in its mouth
#
#
# 2042 /content/gdrive/MyDrive/images/2873837796_543e415e98.jpg
# img_name: /content/gdrive/MyDrive/images/2873837796_543e415e98.jpg
# BLEU-1 score: 42.324086244530704
# BLEU-2 score: 26.768102483623853
# BLEU-3 score: 42.424583401396866
# BLEU-4 score: 47.60116549244004
# Real Caption: black and brown dogs pulling red leash
# Predicted Caption: black dog chewing on red leash
#
#
# 1716 /content/gdrive/MyDrive/images/2716457668_187a6d2b1c.jpg
# img_name: /content/gdrive/MyDrive/images/2716457668_187a6d2b1c.jpg
# BLEU-1 score: 6.02388423824404
# BLEU-2 score: 13.469814645303213
# BLEU-3 score: 18.58470280050952
# BLEU-4 score: 20.142070913129906
# Real Caption: young boy wearing glasses has his hair set to stand up
# Predicted Caption: boy with mohawk and sunglasses
#
#
# 6527 /content/gdrive/MyDrive/images/1510078253_96e9ec50e7.jpg
# img_name: /content/gdrive/MyDrive/images/1510078253_96e9ec50e7.jpg
# BLEU-1 score: 15.766261764490386
# BLEU-2 score: 24.083362654088404
# BLEU-3 score: 28.530703633981965
# BLEU-4 score: 29.765372490051632
# Real Caption: brown dog trying to bite white ball with yellow green and blue puppy toes
# Predicted Caption: two dogs are playing with green ball
#
#
# 7652 /content/gdrive/MyDrive/images/515335111_c4afd5b903.jpg
# img_name: /content/gdrive/MyDrive/images/515335111_c4afd5b903.jpg
# BLEU-1 score: 29.20502936517768
# BLEU-2 score: 47.69161324512283
# BLEU-3 score: 58.02775381138889
# BLEU-4 score: 60.94445482670285
# Real Caption: the man holds wooden paddle in canoe with his dog
# Predicted Caption: man with an orange hat sitting in rowboat
#
#
# 7534 /content/gdrive/MyDrive/images/2587696611_db0378710f.jpg
# img_name: /content/gdrive/MyDrive/images/2587696611_db0378710f.jpg
# BLEU-1 score: 24.39417958443595
# BLEU-2 score: 18.182347935378786
# BLEU-3 score: 13.443642930637218
# BLEU-4 score: 16.166647479823908
# Real Caption: young girl with white dress walks down dirt road with trees and fields on both sides of the road
# Predicted Caption: little girl in white dress is walking down dirt road
#
#
# 1420 /content/gdrive/MyDrive/images/599366440_a238e805cf.jpg
# img_name: /content/gdrive/MyDrive/images/599366440_a238e805cf.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: white dog is trying to play with brown dog
# Predicted Caption: two dogs are playing in the grass
#
#
# 6262 /content/gdrive/MyDrive/images/3568197730_a071d7595b.jpg
# img_name: /content/gdrive/MyDrive/images/3568197730_a071d7595b.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: an <unk> dressed as pirate performs in an outdoor park
# Predicted Caption: skateboarder at high speed skater grinding on green pole
#
#
# 853 /content/gdrive/MyDrive/images/3006926228_cf3c067b3e.jpg
# img_name: /content/gdrive/MyDrive/images/3006926228_cf3c067b3e.jpg
# BLEU-1 score: 15.789473684210522
# BLEU-2 score: 39.73597071195131
# BLEU-3 score: 57.47914456760955
# BLEU-4 score: 63.03647413359293
# Real Caption: the man and one of the women have their hands raised
# Predicted Caption: man in black and white shirt holds drink while being kissed on the cheek by woman in his head
#
#
# 6266 /content/gdrive/MyDrive/images/2623939135_0cd02ffa5d.jpg
# img_name: /content/gdrive/MyDrive/images/2623939135_0cd02ffa5d.jpg
# BLEU-1 score: 31.61336066098961
# BLEU-2 score: 19.142840519891383
# BLEU-3 score: 29.81595120780367
# BLEU-4 score: 33.30881949209662
# Real Caption: woman looking up towards wide ring she is holding over her head drink in her other hand
# Predicted Caption: the girl is holding her necklace and looking up at her
#
#
# 7846 /content/gdrive/MyDrive/images/3445296377_1e5082b44b.jpg
# img_name: /content/gdrive/MyDrive/images/3445296377_1e5082b44b.jpg
# BLEU-1 score: 11.111111111111109
# BLEU-2 score: 33.33333333333333
# BLEU-3 score: 51.72818579717866
# BLEU-4 score: 57.735026918962575
# Real Caption: two children play in the melting <unk>
# Predicted Caption: little girl plays in water next to picnic table
#
#
# 2358 /content/gdrive/MyDrive/images/3204525212_d548c7fca7.jpg
# img_name: /content/gdrive/MyDrive/images/3204525212_d548c7fca7.jpg
# BLEU-1 score: 16.374615061559638
# BLEU-2 score: 36.61475238303926
# BLEU-3 score: 50.518459909936965
# BLEU-4 score: 54.751825350694524
# Real Caption: dogs <unk> plate of food on floor look up at kitchen counter
# Predicted Caption: two large dogs are looking at grey and white cat
#
#
# 7116 /content/gdrive/MyDrive/images/3225025519_c089c14559.jpg
# img_name: /content/gdrive/MyDrive/images/3225025519_c089c14559.jpg
# BLEU-1 score: 30.318287930006566
# BLEU-2 score: 50.277192674896334
# BLEU-3 score: 61.551346607840344
# BLEU-4 score: 64.74469561695607
# Real Caption: man holds microphone in front of another man who is wearing blue hat
# Predicted Caption: man in black cap is eating ice blowing off of corn
#
#
# 7610 /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# img_name: /content/gdrive/MyDrive/images/2559114800_17310f3015.jpg
# BLEU-1 score: 28.57142857142857
# BLEU-2 score: 21.82178902359924
# BLEU-3 score: 40.11753235797364
# BLEU-4 score: 46.71379777282001
# Real Caption: three dogs round bend at racetrack
# Predicted Caption: three dogs are making turn in race
#
#
# 1487 /content/gdrive/MyDrive/images/3383491811_fd9d3a891d.jpg
# img_name: /content/gdrive/MyDrive/images/3383491811_fd9d3a891d.jpg
# BLEU-1 score: 28.57142857142857
# BLEU-2 score: 53.45224838248488
# BLEU-3 score: 68.67198272427282
# BLEU-4 score: 73.11104457090248
# Real Caption: dog licks his nose
# Predicted Caption: brown dog with black collar licking nose
#
#
# 5361 /content/gdrive/MyDrive/images/3500139659_b2a60b0141.jpg
# img_name: /content/gdrive/MyDrive/images/3500139659_b2a60b0141.jpg
# BLEU-1 score: 7.162619921504752
# BLEU-2 score: 14.325239843009504
# BLEU-3 score: 18.902267296570095
# BLEU-4 score: 20.25894847023147
# Real Caption: two motorcyclists are making turn in race one with red themed outfit and bike the other in black
# Predicted Caption: two men on motorcycles are racing at track
#
#
# 5725 /content/gdrive/MyDrive/images/3455920874_6fbec43194.jpg
# img_name: /content/gdrive/MyDrive/images/3455920874_6fbec43194.jpg
# BLEU-1 score: 42.324086244530704
# BLEU-2 score: 37.855813571333776
# BLEU-3 score: 34.45946953219957
# BLEU-4 score: 40.02764942449165
# Real Caption: dog jumps over red and white gate
# Predicted Caption: the dog jumps over an obstacle
#
#
# 7458 /content/gdrive/MyDrive/images/3628103548_2708abcda2.jpg
# img_name: /content/gdrive/MyDrive/images/3628103548_2708abcda2.jpg
# BLEU-1 score: 20.10960138106918
# BLEU-2 score: 12.238313665387365
# BLEU-3 score: 24.16272053105647
# BLEU-4 score: 28.64190457979541
# Real Caption: woman playing guitar and singing in the foreground and three others performing behind her
# Predicted Caption: woman sings into microphone with microphone player in the background
#
#
# 438 /content/gdrive/MyDrive/images/537390477_7dd3407f96.jpg
# img_name: /content/gdrive/MyDrive/images/537390477_7dd3407f96.jpg
# BLEU-1 score: 9.09090909090909
# BLEU-2 score: 30.15113445777636
# BLEU-3 score: 48.70596972258285
# BLEU-4 score: 54.91004867761124
# Real Caption: two dog wrestling
# Predicted Caption: two dark colored dogs are fighting in front of blue building
#
#
# 3110 /content/gdrive/MyDrive/images/3607405494_0df89110a6.jpg
# img_name: /content/gdrive/MyDrive/images/3607405494_0df89110a6.jpg
# BLEU-1 score: 33.33333333333333
# BLEU-2 score: 57.735026918962575
# BLEU-3 score: 71.92230933248644
# BLEU-4 score: 75.98356856515926
# Real Caption: three black dogs wearing muzzles race through the green grass
# Predicted Caption: three dogs leaping up in the air as they compete in race
#
#
# 5271 /content/gdrive/MyDrive/images/2721656220_5f4cda8bc1.jpg
# img_name: /content/gdrive/MyDrive/images/2721656220_5f4cda8bc1.jpg
# BLEU-1 score: 24.902746807698065
# BLEU-2 score: 47.68512970256548
# BLEU-3 score: 61.83541136772769
# BLEU-4 score: 65.9858515800358
# Real Caption: an attractive brunette woman smiles and holds beverage in front of her
# Predicted Caption: the woman is holding glass and looking down at her cellphone
#
#
# 1818 /content/gdrive/MyDrive/images/3518443604_6da641f07d.jpg
# img_name: /content/gdrive/MyDrive/images/3518443604_6da641f07d.jpg
# BLEU-1 score: 22.22222222222222
# BLEU-2 score: 47.14045207910317
# BLEU-3 score: 63.684866956664344
# BLEU-4 score: 68.65890479690393
# Real Caption: two people huddle together on <unk> door stoop
# Predicted Caption: two women with black purse sit on the ground
#
#
# 1715 /content/gdrive/MyDrive/images/2162469360_ff777edc95.jpg
# img_name: /content/gdrive/MyDrive/images/2162469360_ff777edc95.jpg
# BLEU-1 score: 0
# BLEU-2 score: 0
# BLEU-3 score: 0
# BLEU-4 score: 0
# Real Caption: two construction workers working on roof top
# Predicted Caption: man is standing in front of large inflatable equipment
#
#
# 5607 /content/gdrive/MyDrive/images/2710698257_2e4ca8dd44.jpg
# img_name: /content/gdrive/MyDrive/images/2710698257_2e4ca8dd44.jpg
# BLEU-1 score: 72.72727272727273
# BLEU-2 score: 60.30226891555272
# BLEU-3 score: 47.01499970486921
# BLEU-4 score: 31.702331385234306
# Real Caption: man is standing on top of rocks overlooking the ocean
# Predicted Caption: man is standing on the edge of rocks near the ocean
#
#
# 7381 /content/gdrive/MyDrive/images/495014499_8fd065cfd9.jpg
# img_name: /content/gdrive/MyDrive/images/495014499_8fd065cfd9.jpg
# BLEU-1 score: 25.0
# BLEU-2 score: 50.0
# BLEU-3 score: 65.9753955386447
# BLEU-4 score: 70.71067811865476
# Real Caption: man stands on crosswalk holding flag
# Predicted Caption: man in red vest stands in the street
#
#
# 3040 /content/gdrive/MyDrive/images/2717686269_80c4b5ac9e.jpg
# img_name: /content/gdrive/MyDrive/images/2717686269_80c4b5ac9e.jpg
# BLEU-1 score: 25.500152032774785
# BLEU-2 score: 13.523497817747234
# BLEU-3 score: 24.107020450214105
# BLEU-4 score: 27.855256475695363
# Real Caption: small brown and white dog lines on red area rug in patch of sunlight
# Predicted Caption: dog lying on red rug with staring behind them
#
#
# 4933 /content/gdrive/MyDrive/images/2399551242_c62a46dd5f.jpg
# img_name: /content/gdrive/MyDrive/images/2399551242_c62a46dd5f.jpg
# BLEU-1 score: 16.666666666666668
# BLEU-2 score: 40.8248290463863
# BLEU-3 score: 58.419068106786554
# BLEU-4 score: 63.89431042462724
# Real Caption: kids in bathing suits with water splashing around them
# Predicted Caption: young boy is splashing water over his right of another little boy
#
#
# 708 /content/gdrive/MyDrive/images/3127629248_a955b5763b.jpg
# img_name: /content/gdrive/MyDrive/images/3127629248_a955b5763b.jpg
# BLEU-1 score: 26.666666666666668
# BLEU-2 score: 13.801311186847082
# BLEU-3 score: 30.47559608895134
# BLEU-4 score: 37.15011599826719
# Real Caption: basketball player is about to make
# Predicted Caption: the basketball player in white is jumping up to score point against the orange team

# %%
print(f"final BLEU-1 score: {bleu1/160000}")
print(f"final BLEU-2 score: {bleu2/160000}")
print(f"final BLEU-3 score: {bleu3/160000}")
print(f"final BLEU-4 score: {bleu4/160000}")
print(int(len(img_name_val)/5))
# Out:
# final BLEU-1 score: 0.23448979481810303
# final BLEU-2 score: 0.2834708112083052
# final BLEU-3 score: 0.38534081241218343
# final BLEU-4 score: 0.4213975058618965
# 1600
